# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

import numpy as np
import matplotlib.pyplot as plt  # To visualize
import pandas as pd  # To read data
from sklearn.linear_model import LinearRegression

engine = psycopg2.connect(
    database="final-frontier2",
    user="postgres",
    password="TypicalParkerLuck",
    host="final-frontier.czribcwnemzt.us-east-1.rds.amazonaws.com",
    port='5432',
    connect_timeout=3)

#engine #.table_names()
cursor = engine.cursor()

# %%
#results_Query = "select date, match_api_id, home_team_goal, away_team_goal from match where ((home_team_api_id = 8650) and (away_team_api_id = 10260))"
results_Query = "select bwh, bwd, bwa, iwh, iwd, iwa, lbh, lbd, lba, whh, whd, wha, vch, vcd, vca, home_team_goal, away_team_goal \
  from match where ((home_team_api_id = 8650) and (away_team_api_id = 10260)) " #or ((home_team_api_id = 10260) and (away_team_api_id = 8650))"
cursor.execute(results_Query)
game_results = cursor.fetchall()
game_results_pd = pd.DataFrame(game_results,columns=['bwh','bwd', 'bwa', 'iwh', 'iwd', 'iwa', 'lbh', 'lbd', 'lba', 'whh', \
                                                     'whd', 'wha', 'vch', 'vcd', 'vca' ,'home_team_goal', 'away_team_goal'])
game_results_pd
# Out:
#     bwh   bwd   bwa   iwh  iwd   iwa   lbh   lbd   lba   whh   whd  wha   vch  \
# 0   2.8   3.1   2.4   2.6    3   2.6  2.62  2.88   2.5   2.9   3.1  2.5   3.1
# 1  2.85   3.3  2.55   2.7  3.2   2.5   2.8   3.3   2.5  2.88   3.2  2.5   2.6
# 2  2.85  3.25  2.55   2.8  3.2   2.3  2.88   3.2   2.5  2.88   3.2  2.5  2.88
# 3   3.1   3.3  2.35   2.7  3.2   2.4   3.2     3   2.5   3.2   3.1  2.5     3
# 4  2.75   3.4   2.6  2.65  3.2  2.45   2.7   3.2  2.25   2.8  2.88  2.8  2.75
# 5   2.6   3.3  2.65   2.6  3.2   2.6  2.62  3.25  2.62   2.6   3.2  2.8  2.62
# 6  2.15   3.4   3.6   2.2  3.2   3.2   2.1   3.4   3.6   2.1  3.25  3.5   2.1
# 7   2.3   3.1   3.5   2.5  3.2  2.75   2.2  3.25   3.3   2.4   3.1  3.1  2.38
#
#    vcd   vca  home_team_goal  away_team_goal
# 0  3.1   2.5               2               1
# 1  3.2   2.5               2               0
# 2  3.3   2.6               3               1
# 3  3.3   2.5               1               1
# ...

# %%
game_odds_pd = game_results_pd[['bwh','bwd', 'bwa', 'iwh', 'iwd', 'iwa', 'lbh', 'lbd', 'lba', 'whh', 'whd', 'wha', 'vch', 'vcd', 'vca']]
game_odds_HOME = game_odds_pd[['bwh', 'iwh', 'lbh', 'whh', 'vch']]
game_odds_DRAW = game_odds_pd[['bwd', 'iwd', 'lbd', 'whd', 'vcd']]
game_odds_AWAY = game_odds_pd[['bwa', 'iwa', 'lba', 'wha', 'vca']]
game_odds_AWAY
# Out:
#         bwa   iwa   lba   wha   vca
# 0       4.2   3.5  3.75  4.33   4.5
# 1      3.95   3.5   3.5   3.6  3.25
# 2      2.55   2.3   2.5   2.4  2.65
# 3       6.8     6   6.5     6   6.5
# 4       1.6   1.7  1.72   1.7  1.65
# ...     ...   ...   ...   ...   ...
# 25974  None  None  None  None  None
# 25975  None  None  None  None  None
# 25976  None  None  None  None  None
# 25977  None  None  None  None  None
# 25978  None  None  None  None  None
#
# [25979 rows x 5 columns]

# %%
# Select home player roster for when MUN played at Liverpool

drop_Query = "drop table if exists livvman;"
cursor.execute(drop_Query)


sel_liv_home_Query = "select distinct p.player_name, p.player_api_id, m.home_team_api_id \
                into temporary table livvman from player p, \
                match m where ((p.player_api_id = m.home_player_1) \
                               or (p.player_api_id = m.home_player_2) \
                               or (p.player_api_id = m.home_player_3) \
                               or (p.player_api_id = m.home_player_4) \
                               or (p.player_api_id = m.home_player_5) \
                               or (p.player_api_id = m.home_player_6) \
                               or (p.player_api_id = m.home_player_7) \
                               or (p.player_api_id = m.home_player_8) \
                               or (p.player_api_id = m.home_player_9) \
                               or (p.player_api_id = m.home_player_10) \
                               or (p.player_api_id = m.home_player_11)) \
                and ((m.home_team_api_id = 8650) and (away_team_api_id = 10260));"

cursor.execute(sel_liv_home_Query)
join_liv_home_Query = "select * from livvman \
                  left join player_attributes \
                  on livvman.player_api_id = player_attributes.player_api_id;"
cursor.execute(join_liv_home_Query)

liverpool_home = cursor.fetchall()
liv_home_df = pd.DataFrame(liverpool_home,columns=['player_name','player_api_id','home_team_api_id','id',\
                'player_fifa_api_id','player_api_id-2','date','overall_rating','potential','preferred_foot','attacking_work_rate',\
                'free_kick_accuracy','long_passing','ball_control','acceleration','sprint_speed','agility','reactions','balance',\
                'shot_power','jumping','stamina','strength','long_shots','aggression','interceptions','positioning','vision','penalties',\
                'marking','standing_tackle','sliding_tackle','gk_diving','gk_handling','gk_kicking','gk_positioning','gk_reflexes'])


liv_home_df['date'] = pd.to_datetime(liv_home_df['date']).dt.date

#df['birth_date'] > start_date) & (df['birth_date'] <= end_date

#mask = (liv_home_df['date'] = '2011-03-06') # & (liv_home_df['date'] <= '2011-03-07')

#df = liv_home_df.loc['date' = '2011-03-06']

liv_home_df
# Out:
#        player_name  player_api_id  home_team_api_id      id  \
# 0     Daniel Agger          25984              8650   34763
# 1     Daniel Agger          25984              8650   34762
# 2     Daniel Agger          25984              8650   34761
# 3     Daniel Agger          25984              8650   34760
# 4     Daniel Agger          25984              8650   34759
# ...            ...            ...               ...     ...
# 1169   Lucas Leiva          95327              8650  104535
# 1170   Lucas Leiva          95327              8650  104534
# 1171   Lucas Leiva          95327              8650  104533
# 1172   Lucas Leiva          95327              8650  104532
# 1173   Lucas Leiva          95327              8650  104531
#
#       player_fifa_api_id  player_api_id-2        date  overall_rating  \
# 0                 152039            25984  2007-02-22            72.0
# 1                 152039            25984  2007-08-30            83.0
# ...

# %%
# Select away player roster for when MUN played at Liverpool

drop_Query = "drop table if exists manvliv;"
cursor.execute(drop_Query)

sel_man_away_Query = "select distinct p.player_name, p.player_api_id, m.away_team_api_id \
              into temporary table manvliv from player p, \
              match m where ((p.player_api_id = m.away_player_1) \
                              or (p.player_api_id = m.away_player_2) \
                              or (p.player_api_id = m.away_player_3) \
                              or (p.player_api_id = m.away_player_4) \
                              or (p.player_api_id = m.away_player_5) \
                              or (p.player_api_id = m.away_player_6) \
                              or (p.player_api_id = m.away_player_7) \
                              or (p.player_api_id = m.away_player_8) \
                              or (p.player_api_id = m.away_player_9) \
                              or (p.player_api_id = m.away_player_10) \
                              or (p.player_api_id = m.away_player_11)) \
            and ((m.away_team_api_id = 10260) and (home_team_api_id = 8650));"
cursor.execute(sel_man_away_Query)

join_man_away_Query = "select * from manvliv left join player_attributes \
                  on manvliv.player_api_id = player_attributes.player_api_id;"
cursor.execute(join_man_away_Query)

man_away = cursor.fetchall()
man_away_df = pd.DataFrame(man_away,columns=['player_name','player_api_id','home_team_api_id','id','player_fifa_api_id','player_api_id-2','date',\
                'overall_rating','potential','preferred_foot','attacking_work_rate','defensive_work_rate','crossing','finishing','heading_accuracy',\
                'short_passing','volleys','dribbling','curve','free_kick_accuracy','long_passing','ball_control','acceleration','sprint_speed',\
                'agility','reactions','balance','shot_power','jumping','stamina','strength','long_shots','aggression','interceptions','positioning',\
                'vision','penalties','marking','standing_tackle','sliding_tackle','gk_diving','gk_handling','gk_kicking','gk_positioning','gk_reflexes'])
man_away_df
# Out:
#         player_name  player_api_id  home_team_api_id     id  \
# 0     Danny Welbeck         113836             10260  37686
# 1     Danny Welbeck         113836             10260  37685
# 2     Danny Welbeck         113836             10260  37684
# 3     Danny Welbeck         113836             10260  37683
# 4     Danny Welbeck         113836             10260  37682
# ...             ...            ...               ...    ...
# 1031   Ji-Sung Park          30802             10260  81842
# 1032   Ji-Sung Park          30802             10260  81841
# 1033   Ji-Sung Park          30802             10260  81840
# 1034   Ji-Sung Park          30802             10260  81839
# 1035   Ji-Sung Park          30802             10260  81838
#
#       player_fifa_api_id  player_api_id-2                 date  \
# 0                 186146           113836  2007-02-22 00:00:00
# 1                 186146           113836  2008-08-30 00:00:00
# ...

# %%
#data = liv_home_df[["overall_rating","potential","agility","shot_power","strength","aggression"]]
liv_data = liv_home_df[["overall_rating","potential","shot_power","aggression"]]
liv_cdata = liv_data.dropna(how='any')
#data = data.apply(pd.to_numeric, errors='coerce')

man_data = man_away_df[["overall_rating","potential","shot_power","aggression"]]
man_cdata = liv_data.dropna(how='any')

#data.replace('', np.nan, inplace=True)
#liv_cdata.isnull().sum().sum()
#cleandata
man_cdata.isnull().sum().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-c73e41a8f8b9> in <module>
#       1 #data = liv_home_df[["overall_rating","potential","agility","shot_power","strength","aggression"]]
# ----> 2 liv_data = liv_home_df[["overall_rating","potential","shot_power","aggression"]]
#       3 liv_cdata = liv_data.dropna(how='any')
#       4 #data = data.apply(pd.to_numeric, errors='coerce')
#       5
#
# NameError: name 'liv_home_df' is not defined

# %%
man_cdata
# Out:
#       overall_rating  potential  shot_power  aggression
# 0               72.0       89.0        58.0        77.0
# 1               83.0       86.0        80.0        77.0
# 2               82.0       86.0        80.0        78.0
# 3               82.0       86.0        80.0        78.0
# 4               81.0       86.0        86.0        78.0
# ...              ...        ...         ...         ...
# 1169            80.0       82.0        71.0        83.0
# 1170            80.0       82.0        71.0        83.0
# 1171            79.0       79.0        71.0        83.0
# 1172            79.0       79.0        71.0        83.0
# 1173            79.0       79.0        71.0        83.0
#
# [1171 rows x 4 columns]

# %%
#data = liv_home_df['overall_rating','potential','agility','shot_power','strength','agression']  # load data set
#X = liv_cdata.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
#Y = liv_cdata.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
odds_HOME = game_odds_HOME.dropna(how='any')
X = odds_HOME.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = odds_HOME.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.rcParams["figure.figsize"] = (10,10)
plt.show()

# %%
odds_DRAW = game_odds_DRAW.dropna(how='any')
X = odds_DRAW.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = odds_DRAW.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions
#figure(figsize=(8, 6), dpi=80)

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.rcParams["figure.figsize"] = (10,10)
plt.show()

# %%
odds_AWAY = game_odds_AWAY.dropna(how='any')
X = odds_AWAY.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = odds_AWAY.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.rcParams["figure.figsize"] = (10,10)
plt.show()

# %%
# Out:
# D:\Users\dan\anaconda3\lib\site-packages\sklearn\cluster\_affinity_propagation.py:148: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 1.0 (renaming of 0.25) which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(
# D:\Users\dan\anaconda3\lib\site-packages\sklearn\cluster\_affinity_propagation.py:148: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 1.0 (renaming of 0.25) which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(
# ...
