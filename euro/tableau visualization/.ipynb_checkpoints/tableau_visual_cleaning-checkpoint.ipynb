# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"../tableau visualization/playerattri.csv")
df
# Out:
#             id  player_fifa_api_id  player_api_id             date  \
# 0            1              218353         505942   2/18/2016 0:00
# 1            2              218353         505942  11/19/2015 0:00
# 2            3              218353         505942   9/21/2015 0:00
# 3            4              218353         505942   3/20/2015 0:00
# 4            5              218353         505942   2/22/2007 0:00
# ...        ...                 ...            ...              ...
# 183973  183974              102359          39902   8/30/2009 0:00
# 183974  183975              102359          39902   2/22/2009 0:00
# 183975  183976              102359          39902   8/30/2008 0:00
# 183976  183977              102359          39902   8/30/2007 0:00
# 183977  183978              102359          39902   2/22/2007 0:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# 0                 67.0       71.0          right              medium
# ...

# %%
df.dtypes
# Out:
# id                       int64
# player_fifa_api_id       int64
# player_api_id            int64
# date                    object
# overall_rating         float64
# potential              float64
# preferred_foot          object
# attacking_work_rate     object
# defensive_work_rate     object
# crossing               float64
# finishing              float64
# heading_accuracy       float64
# short_passing          float64
# volleys                float64
# dribbling              float64
# curve                  float64
# free_kick_accuracy     float64
# long_passing           float64
# ball_control           float64
# acceleration           float64
# sprint_speed           float64
# agility                float64
# reactions              float64
# balance                float64
# shot_power             float64
# jumping                float64
# stamina                float64
# strength               float64
# long_shots             float64
# aggression             float64
# ...

# %%
df.drop(["id"],axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
options = ['medium', 'high', 'low']
df1 = df[df.attacking_work_rate.isin(options)]

# %%
options = ['medium', 'high', 'low']
df2 = df1[df1.defensive_work_rate.isin(options)]

# %%
df3=df2.copy()

# %%
df3.drop(['player_api_id','gk_diving','gk_reflexes','gk_positioning','sliding_tackle','standing_tackle','dribbling','short_passing','volleys','sprint_speed','agility','balance','curve','vision','potential'],axis=1,inplace=True)

# %%
df3.drop(['date'],axis=1,inplace=True)

# %%
df3
# Out:
#         player_fifa_api_id  overall_rating preferred_foot attacking_work_rate  \
# 0                   218353            67.0          right              medium
# 1                   218353            67.0          right              medium
# 2                   218353            62.0          right              medium
# 3                   218353            61.0          right              medium
# 4                   218353            61.0          right              medium
# ...                    ...             ...            ...                 ...
# 183973              102359            83.0          right              medium
# 183974              102359            78.0          right              medium
# 183975              102359            77.0          right              medium
# 183976              102359            78.0          right              medium
# 183977              102359            80.0          right              medium
#
# ...

# %%
df3.to_excel("tableau_visual_data.xlsx")
