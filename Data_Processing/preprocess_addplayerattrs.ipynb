# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pandas as pd

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///C:/Users/JoshWeidenaar/Downloads/database.sqlite")

# %%
engine
# Out:
# Engine(sqlite:///C:/Users/JoshWeidenaar/Downloads/database.sqlite)

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# Create a session
session = Session(engine)

# %%
# Print all of the classes mapped to the Base
classes = Base.classes.keys()

# %%
df_dict = {}

for i in classes:
    class_call = Base.classes[i]
    class_data = session.query(class_call).all()
    listie_dicts = []
    for j in class_data:
        listie_dicts.append(j.__dict__)
    df_dict[i] = pd.DataFrame(listie_dicts)
# Out:
# C:\Users\JoshWeidenaar\anaconda3\lib\site-packages\sqlalchemy\sql\sqltypes.py:661: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   util.warn(

# %%
classes
# Out:
# ['Country',
#  'League',
#  'country',
#  'Match',
#  'Player',
#  'Team',
#  'Player_Attributes',
#  'Team_Attributes']

# %%
country_id = df_dict['country']['id']
country_id_LEAGUE = df_dict['League']['country_id']
league_id = df_dict['League']['id']

# %%
league_id_MATCH = df_dict['Match']['league_id']
country_id_MATCH = df_dict['Match']['country_id']
home_team_api_id_MATCH = df_dict['Match']['home_team_api_id']
away_team_api_id_MATCH = df_dict['Match']['away_team_api_id'] 
player_id_MATCH = []#any attr in Match table that has the word "player" in it
player_id = df_dict['Player']['id']
player_api_id = df_dict['Player']['player_api_id']
player_fifa_id = df_dict['Player']['player_fifa_api_id']
player_attr_id = df_dict['Player_Attributes']['id']
player_id_ATTRS = df_dict['Player_Attributes']['player_api_id']
player_fifa_id_ATTRS = df_dict['Player_Attributes']['player_fifa_api_id']
team_fifa_id = df_dict['Team']['team_fifa_api_id']
team_id = df_dict['Team']['id']
team_api_id = df_dict['Team']['team_api_id']
team_id_ATTRS = df_dict['Team_Attributes']['team_api_id']
team_fifa_id_ATTRS = df_dict['Team_Attributes']['team_fifa_api_id']

# %%
player_merged = pd.merge(df_dict['Player'],df_dict['Player_Attributes'],left_on=player_api_id,right_on=player_id_ATTRS)
print(len(df_dict['Player_Attributes']) - len(player_merged))
# Out:
# 0

# %%
team_merged = pd.merge(df_dict['Team'],df_dict['Team_Attributes'],left_on=team_api_id ,right_on=team_id_ATTRS)
print(len(df_dict['Team_Attributes']) - len(team_merged))
# Out:
# 0

# %%
league_merged = pd.merge(df_dict['League'],df_dict['Country'],left_on=country_id_LEAGUE,right_on=country_id)
print(len(df_dict['League']) - len(league_merged))
# Out:
# 0

# %%
sqlite_ddl = """CREATE TABLE "Country" (
	"id"	INTEGER,
	"name"	TEXT UNIQUE,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "League" (
	"id"	INTEGER,
	"country_id"	INTEGER,
	"name"	TEXT UNIQUE,
	FOREIGN KEY("country_id") REFERENCES "country"("id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Match" (
	"id"	INTEGER,
	"country_id"	INTEGER,
	"league_id"	INTEGER,
	"season"	TEXT,
	"stage"	INTEGER,
	"date"	TEXT,
	"match_api_id"	INTEGER UNIQUE,
	"home_team_api_id"	INTEGER,
	"away_team_api_id"	INTEGER,
	"home_team_goal"	INTEGER,
	"away_team_goal"	INTEGER,
	"home_player_X1"	INTEGER,
	"home_player_X2"	INTEGER,
	"home_player_X3"	INTEGER,
	"home_player_X4"	INTEGER,
	"home_player_X5"	INTEGER,
	"home_player_X6"	INTEGER,
	"home_player_X7"	INTEGER,
	"home_player_X8"	INTEGER,
	"home_player_X9"	INTEGER,
	"home_player_X10"	INTEGER,
	"home_player_X11"	INTEGER,
	"away_player_X1"	INTEGER,
	"away_player_X2"	INTEGER,
	"away_player_X3"	INTEGER,
	"away_player_X4"	INTEGER,
	"away_player_X5"	INTEGER,
	"away_player_X6"	INTEGER,
	"away_player_X7"	INTEGER,
	"away_player_X8"	INTEGER,
	"away_player_X9"	INTEGER,
	"away_player_X10"	INTEGER,
	"away_player_X11"	INTEGER,
	"home_player_Y1"	INTEGER,
	"home_player_Y2"	INTEGER,
	"home_player_Y3"	INTEGER,
	"home_player_Y4"	INTEGER,
	"home_player_Y5"	INTEGER,
	"home_player_Y6"	INTEGER,
	"home_player_Y7"	INTEGER,
	"home_player_Y8"	INTEGER,
	"home_player_Y9"	INTEGER,
	"home_player_Y10"	INTEGER,
	"home_player_Y11"	INTEGER,
	"away_player_Y1"	INTEGER,
	"away_player_Y2"	INTEGER,
	"away_player_Y3"	INTEGER,
	"away_player_Y4"	INTEGER,
	"away_player_Y5"	INTEGER,
	"away_player_Y6"	INTEGER,
	"away_player_Y7"	INTEGER,
	"away_player_Y8"	INTEGER,
	"away_player_Y9"	INTEGER,
	"away_player_Y10"	INTEGER,
	"away_player_Y11"	INTEGER,
	"home_player_1"	INTEGER,
	"home_player_2"	INTEGER,
	"home_player_3"	INTEGER,
	"home_player_4"	INTEGER,
	"home_player_5"	INTEGER,
	"home_player_6"	INTEGER,
	"home_player_7"	INTEGER,
	"home_player_8"	INTEGER,
	"home_player_9"	INTEGER,
	"home_player_10"	INTEGER,
	"home_player_11"	INTEGER,
	"away_player_1"	INTEGER,
	"away_player_2"	INTEGER,
	"away_player_3"	INTEGER,
	"away_player_4"	INTEGER,
	"away_player_5"	INTEGER,
	"away_player_6"	INTEGER,
	"away_player_7"	INTEGER,
	"away_player_8"	INTEGER,
	"away_player_9"	INTEGER,
	"away_player_10"	INTEGER,
	"away_player_11"	INTEGER,
	"goal"	TEXT,
	"shoton"	TEXT,
	"shotoff"	TEXT,
	"foulcommit"	TEXT,
	"card"	TEXT,
	"cross"	TEXT,
	"corner"	TEXT,
	"possession"	TEXT,
	"B365H"	NUMERIC,
	"B365D"	NUMERIC,
	"B365A"	NUMERIC,
	"BWH"	NUMERIC,
	"BWD"	NUMERIC,
	"BWA"	NUMERIC,
	"IWH"	NUMERIC,
	"IWD"	NUMERIC,
	"IWA"	NUMERIC,
	"LBH"	NUMERIC,
	"LBD"	NUMERIC,
	"LBA"	NUMERIC,
	"PSH"	NUMERIC,
	"PSD"	NUMERIC,
	"PSA"	NUMERIC,
	"WHH"	NUMERIC,
	"WHD"	NUMERIC,
	"WHA"	NUMERIC,
	"SJH"	NUMERIC,
	"SJD"	NUMERIC,
	"SJA"	NUMERIC,
	"VCH"	NUMERIC,
	"VCD"	NUMERIC,
	"VCA"	NUMERIC,
	"GBH"	NUMERIC,
	"GBD"	NUMERIC,
	"GBA"	NUMERIC,
	"BSH"	NUMERIC,
	"BSD"	NUMERIC,
	"BSA"	NUMERIC,
	FOREIGN KEY("home_player_9") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_1") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_10") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_2") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_3") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_4") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_5") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_6") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_11") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_5") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_7") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_4") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_9") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_10") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_7") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_6") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_8") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_8") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_team_api_id") REFERENCES "Team"("team_api_id"),
	FOREIGN KEY("home_player_1") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_3") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_2") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("country_id") REFERENCES "country"("id"),
	FOREIGN KEY("league_id") REFERENCES "League"("id"),
	FOREIGN KEY("home_team_api_id") REFERENCES "Team"("team_api_id"),
	FOREIGN KEY("away_player_11") REFERENCES "Player"("player_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Player" (
	"id"	INTEGER,
	"player_api_id"	INTEGER UNIQUE,
	"player_name"	TEXT,
	"player_fifa_api_id"	INTEGER UNIQUE,
	"birthday"	TEXT,
	"height"	INTEGER,
	"weight"	INTEGER,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
​
CREATE TABLE "Player_Attributes" (
	"id"	INTEGER,
	"player_fifa_api_id"	INTEGER,
	"player_api_id"	INTEGER,
	"date"	TEXT,
	"overall_rating"	INTEGER,
	"potential"	INTEGER,
	"preferred_foot"	TEXT,
	"attacking_work_rate"	TEXT,
	"defensive_work_rate"	TEXT,
	"crossing"	INTEGER,
	"finishing"	INTEGER,
	"heading_accuracy"	INTEGER,
	"short_passing"	INTEGER,
	"volleys"	INTEGER,
	"dribbling"	INTEGER,
	"curve"	INTEGER,
	"free_kick_accuracy"	INTEGER,
	"long_passing"	INTEGER,
	"ball_control"	INTEGER,
	"acceleration"	INTEGER,
	"sprint_speed"	INTEGER,
	"agility"	INTEGER,
	"reactions"	INTEGER,
	"balance"	INTEGER,
	"shot_power"	INTEGER,
	"jumping"	INTEGER,
	"stamina"	INTEGER,
	"strength"	INTEGER,
	"long_shots"	INTEGER,
	"aggression"	INTEGER,
	"interceptions"	INTEGER,
	"positioning"	INTEGER,
	"vision"	INTEGER,
	"penalties"	INTEGER,
	"marking"	INTEGER,
	"standing_tackle"	INTEGER,
	"sliding_tackle"	INTEGER,
	"gk_diving"	INTEGER,
	"gk_handling"	INTEGER,
	"gk_kicking"	INTEGER,
	"gk_positioning"	INTEGER,
	"gk_reflexes"	INTEGER,
	FOREIGN KEY("player_fifa_api_id") REFERENCES "Player"("player_fifa_api_id"),
	FOREIGN KEY("player_api_id") REFERENCES "Player"("player_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Team" (
	"id"	INTEGER,
	"team_api_id"	INTEGER UNIQUE,
	"team_fifa_api_id"	INTEGER,
	"team_long_name"	TEXT,
	"team_short_name"	TEXT,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Team_Attributes" (
	"id"	INTEGER,
	"team_fifa_api_id"	INTEGER,
	"team_api_id"	INTEGER,
	"date"	TEXT,
	"buildUpPlaySpeed"	INTEGER,
	"buildUpPlaySpeedClass"	TEXT,
	"buildUpPlayDribbling"	INTEGER,
	"buildUpPlayDribblingClass"	TEXT,
	"buildUpPlayPassing"	INTEGER,
	"buildUpPlayPassingClass"	TEXT,
	"buildUpPlayPositioningClass"	TEXT,
	"chanceCreationPassing"	INTEGER,
	"chanceCreationPassingClass"	TEXT,
	"chanceCreationCrossing"	INTEGER,
	"chanceCreationCrossingClass"	TEXT,
	"chanceCreationShooting"	INTEGER,
	"chanceCreationShootingClass"	TEXT,
	"chanceCreationPositioningClass"	TEXT,
	"defencePressure"	INTEGER,
	"defencePressureClass"	TEXT,
	"defenceAggression"	INTEGER,
	"defenceAggressionClass"	TEXT,
	"defenceTeamWidth"	INTEGER,
	"defenceTeamWidthClass"	TEXT,
	"defenceDefenderLineClass"	TEXT,
	FOREIGN KEY("team_fifa_api_id") REFERENCES "Team"("team_fifa_api_id"),
	FOREIGN KEY("team_api_id") REFERENCES "Team"("team_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "sqlite_sequence" (
	"name"	,
	"seq"
);"""

# %%
import datetime as dt

# %%
team_merged['YEAR'] = [dt.date(int(i.split('-')[0]),1,1) for i in team_merged.date]

# %%
df_dict['Match']['YEAR'] = [dt.date(int(i.split('-')[0]),1,1) for i in df_dict['Match'].date]

# %%
merge_team_away = pd.merge(df_dict['Match'],team_merged,left_on=[away_team_api_id_MATCH,'YEAR'],right_on=['team_api_id_x','YEAR'])

# %%
merge_team_home = pd.merge(df_dict['Match'],team_merged,left_on=[home_team_api_id_MATCH,'YEAR'],right_on=['team_api_id_x','YEAR'])

# %%
match_merged = pd.merge(merge_team_home,merge_team_away,left_on=['id','YEAR'],right_on=['id','YEAR'],suffixes=('_HOME','_AWAY'))
len(match_merged)
# Out:
# 18243

# %%
match_merged
# Out:
#                                  _sa_instance_state_HOME  country_id_HOME  \
# 0      <sqlalchemy.orm.state.InstanceState object at ...                1
# 1      <sqlalchemy.orm.state.InstanceState object at ...                1
# 2      <sqlalchemy.orm.state.InstanceState object at ...                1
# 3      <sqlalchemy.orm.state.InstanceState object at ...                1
# 4      <sqlalchemy.orm.state.InstanceState object at ...                1
# ...                                                  ...              ...
# 18238  <sqlalchemy.orm.state.InstanceState object at ...            24558
# 18239  <sqlalchemy.orm.state.InstanceState object at ...            24558
# 18240  <sqlalchemy.orm.state.InstanceState object at ...            24558
# 18241  <sqlalchemy.orm.state.InstanceState object at ...            24558
# 18242  <sqlalchemy.orm.state.InstanceState object at ...            24558
#
#        away_player_Y6_HOME                                          card_HOME  \
# 0                      7.0                                               None
# 1                      7.0                                               None
# 2                      7.0                                               None
# 3                      7.0                                               None
# 4                      3.0                                               None
# ...                    ...                                                ...
# 18238                  6.0                                               None
# 18239                  7.0  <card><value><comment>y</comment><stats><ycard...
# 18240                  6.0                                               None
# 18241                  7.0                                               None
# 18242                  6.0                                               None
#
#       PSH_HOME  league_id_HOME  away_player_Y7_HOME cross_HOME PSD_HOME  \
# 0         None               1                  7.0       None     None
# 1         None               1                  7.0       None     None
# 2         None               1                  7.0       None     None
# 3         None               1                  7.0       None     None
# 4         None               1                  7.0       None     None
# ...        ...             ...                  ...        ...      ...
# 18238     None           24558                  6.0       None     None
# 18239     None           24558                  7.0  <cross />     None
# 18240     None           24558                  6.0       None     None
# 18241     None           24558                  7.0       None     None
# 18242     None           24558                  6.0       None     None
#
#       season_HOME  ...  defenceDefenderLineClass_AWAY id_y_AWAY  \
# 0       2009/2010  ...                          Cover       319
# 1       2009/2010  ...                          Cover      1234
# 2       2009/2010  ...                          Cover       660
# 3       2009/2010  ...                          Cover       485
# 4       2010/2011  ...                          Cover      1391
# ...           ...  ...                            ...       ...
# 18238   2015/2016  ...                          Cover       776
# 18239   2015/2016  ...                          Cover      1269
# 18240   2015/2016  ...                          Cover      1215
# 18241   2015/2016  ...                          Cover       451
# 18242   2015/2016  ...                          Cover      1439
#
#       chanceCreationShootingClass_AWAY  buildUpPlayPassingClass_AWAY  \
# 0                               Normal                         Mixed
# 1                               Normal                         Mixed
# 2                               Normal                         Mixed
# 3                               Normal                         Mixed
# 4                               Normal                         Mixed
# ...                                ...                           ...
# 18238                           Normal                         Mixed
# 18239                           Normal                         Mixed
# 18240                           Normal                         Mixed
# 18241                           Normal                         Mixed
# 18242                           Normal                         Mixed
#
#        chanceCreationPositioningClass_AWAY team_fifa_api_id_y_AWAY  \
# 0                                Organised                     231
# 1                                Organised                     680
# 2                                Organised                  110724
# 3                                Organised                     673
# 4                                Organised                     681
# ...                                    ...                     ...
# 18238                            Organised                     897
# 18239                            Organised                    1715
# 18240                            Organised                     898
# 18241                            Organised                     894
# 18242                            Organised                     900
#
#       buildUpPlayPositioningClass_AWAY team_api_id_y_AWAY  \
# 0                            Organised               8342
# 1                            Organised               9997
# 2                            Organised               8203
# 3                            Organised               9987
# 4                            Organised              10001
# ...                                ...                ...
# 18238                        Organised              10199
# 18239                        Organised              10191
# 18240                        Organised              10190
# 18241                        Organised              10243
# 18242                        Organised              10192
#
#        defencePressure_AWAY          date_y_AWAY
# 0                        60  2010-02-22 00:00:00
# 1                        50  2010-02-22 00:00:00
# 2                        60  2010-02-22 00:00:00
# 3                        70  2010-02-22 00:00:00
# 4                        70  2010-02-22 00:00:00
# ...                     ...                  ...
# 18238                    48  2015-09-10 00:00:00
# 18239                    47  2015-09-10 00:00:00
# 18240                    40  2015-09-10 00:00:00
# 18241                    47  2015-09-10 00:00:00
# 18242                    44  2015-09-10 00:00:00
#
# [18243 rows x 298 columns]

# %%
match_merged.columns.tolist()
# Out:
# ['_sa_instance_state_HOME',
#  'country_id_HOME',
#  'away_player_Y6_HOME',
#  'card_HOME',
#  'PSH_HOME',
#  'league_id_HOME',
#  'away_player_Y7_HOME',
#  'cross_HOME',
#  'PSD_HOME',
#  'season_HOME',
#  'away_player_Y8_HOME',
#  'corner_HOME',
#  'PSA_HOME',
#  'stage_HOME',
#  'away_player_Y9_HOME',
#  'possession_HOME',
#  'WHH_HOME',
#  'date_x_HOME',
#  'away_player_Y10_HOME',
#  'B365H_HOME',
#  'WHD_HOME',
#  'match_api_id_HOME',
#  'away_player_Y11_HOME',
#  'B365D_HOME',
#  'WHA_HOME',
#  'home_team_api_id_HOME',
#  'home_player_1_HOME',
#  'B365A_HOME',
#  'SJH_HOME',
#  'away_team_api_id_HOME',
#  'home_player_2_HOME',
#  'BWH_HOME',
#  'SJD_HOME',
#  'home_player_3_HOME',
#  'home_team_goal_HOME',
#  'BWD_HOME',
#  'SJA_HOME',
#  'away_team_goal_HOME',
#  'home_player_4_HOME',
#  'BWA_HOME',
#  'VCH_HOME',
#  'home_player_X1_HOME',
#  'home_player_5_HOME',
#  'IWH_HOME',
#  'VCD_HOME',
#  'home_player_X2_HOME',
#  'home_player_6_HOME',
#  'IWD_HOME',
#  'VCA_HOME',
#  'home_player_X3_HOME',
#  'home_player_7_HOME',
#  'IWA_HOME',
#  'GBH_HOME',
#  'home_player_X4_HOME',
#  'home_player_8_HOME',
#  'LBH_HOME',
#  'GBD_HOME',
#  'home_player_X5_HOME',
#  'home_player_9_HOME',
#  'LBD_HOME',
#  'GBA_HOME',
#  'home_player_X6_HOME',
#  'home_player_10_HOME',
#  'LBA_HOME',
#  'BSH_HOME',
#  'home_player_X7_HOME',
#  'home_player_Y1_HOME',
#  'home_player_11_HOME',
#  'BSD_HOME',
#  'home_player_X8_HOME',
#  'home_player_Y2_HOME',
#  'away_player_1_HOME',
#  'BSA_HOME',
#  'home_player_X9_HOME',
#  'home_player_Y3_HOME',
#  'away_player_2_HOME',
#  'home_player_X10_HOME',
#  'home_player_Y4_HOME',
#  'away_player_3_HOME',
#  'home_player_X11_HOME',
#  'home_player_Y5_HOME',
#  'away_player_4_HOME',
#  'away_player_X1_HOME',
#  'home_player_Y6_HOME',
#  'away_player_5_HOME',
#  'away_player_X2_HOME',
#  'home_player_Y7_HOME',
#  'away_player_6_HOME',
#  'away_player_X3_HOME',
#  'home_player_Y8_HOME',
#  'away_player_7_HOME',
#  'away_player_X4_HOME',
#  'home_player_Y9_HOME',
#  'away_player_8_HOME',
#  'away_player_X5_HOME',
#  'home_player_Y10_HOME',
#  'away_player_9_HOME',
#  'away_player_X6_HOME',
#  'home_player_Y11_HOME',
#  'away_player_10_HOME',
#  'away_player_X7_HOME',
#  'away_player_Y1_HOME',
#  'away_player_11_HOME',
#  'away_player_X8_HOME',
#  'away_player_Y2_HOME',
#  'goal_HOME',
#  'away_player_X9_HOME',
#  'away_player_Y3_HOME',
#  'shoton_HOME',
#  'away_player_X10_HOME',
#  'away_player_Y4_HOME',
#  'shotoff_HOME',
#  'id',
#  'away_player_X11_HOME',
#  'away_player_Y5_HOME',
#  'foulcommit_HOME',
#  'YEAR',
#  'key_0_HOME',
#  '_sa_instance_state_x_HOME',
#  'team_short_name_HOME',
#  'team_fifa_api_id_x_HOME',
#  'id_x_HOME',
#  'team_api_id_x_HOME',
#  'team_long_name_HOME',
#  '_sa_instance_state_y_HOME',
#  'chanceCreationPassing_HOME',
#  'buildUpPlaySpeed_HOME',
#  'defenceAggression_HOME',
#  'chanceCreationPassingClass_HOME',
#  'buildUpPlaySpeedClass_HOME',
#  'defenceAggressionClass_HOME',
#  'chanceCreationCrossing_HOME',
#  'buildUpPlayDribbling_HOME',
#  'defenceTeamWidth_HOME',
#  'defencePressureClass_HOME',
#  'chanceCreationCrossingClass_HOME',
#  'buildUpPlayDribblingClass_HOME',
#  'defenceTeamWidthClass_HOME',
#  'chanceCreationShooting_HOME',
#  'buildUpPlayPassing_HOME',
#  'defenceDefenderLineClass_HOME',
#  'id_y_HOME',
#  'chanceCreationShootingClass_HOME',
#  'buildUpPlayPassingClass_HOME',
#  'chanceCreationPositioningClass_HOME',
#  'team_fifa_api_id_y_HOME',
#  'buildUpPlayPositioningClass_HOME',
#  'team_api_id_y_HOME',
#  'defencePressure_HOME',
#  'date_y_HOME',
#  '_sa_instance_state_AWAY',
#  'country_id_AWAY',
#  'away_player_Y6_AWAY',
#  'card_AWAY',
#  'PSH_AWAY',
#  'league_id_AWAY',
#  'away_player_Y7_AWAY',
#  'cross_AWAY',
#  'PSD_AWAY',
#  'season_AWAY',
#  'away_player_Y8_AWAY',
#  'corner_AWAY',
#  'PSA_AWAY',
#  'stage_AWAY',
#  'away_player_Y9_AWAY',
#  'possession_AWAY',
#  'WHH_AWAY',
#  'date_x_AWAY',
#  'away_player_Y10_AWAY',
#  'B365H_AWAY',
#  'WHD_AWAY',
#  'match_api_id_AWAY',
#  'away_player_Y11_AWAY',
#  'B365D_AWAY',
#  'WHA_AWAY',
#  'home_team_api_id_AWAY',
#  'home_player_1_AWAY',
#  'B365A_AWAY',
#  'SJH_AWAY',
#  'away_team_api_id_AWAY',
#  'home_player_2_AWAY',
#  'BWH_AWAY',
#  'SJD_AWAY',
#  'home_player_3_AWAY',
#  'home_team_goal_AWAY',
#  'BWD_AWAY',
#  'SJA_AWAY',
#  'away_team_goal_AWAY',
#  'home_player_4_AWAY',
#  'BWA_AWAY',
#  'VCH_AWAY',
#  'home_player_X1_AWAY',
#  'home_player_5_AWAY',
#  'IWH_AWAY',
#  'VCD_AWAY',
#  'home_player_X2_AWAY',
#  'home_player_6_AWAY',
#  'IWD_AWAY',
#  'VCA_AWAY',
#  'home_player_X3_AWAY',
#  'home_player_7_AWAY',
#  'IWA_AWAY',
#  'GBH_AWAY',
#  'home_player_X4_AWAY',
#  'home_player_8_AWAY',
#  'LBH_AWAY',
#  'GBD_AWAY',
#  'home_player_X5_AWAY',
#  'home_player_9_AWAY',
#  'LBD_AWAY',
#  'GBA_AWAY',
#  'home_player_X6_AWAY',
#  'home_player_10_AWAY',
#  'LBA_AWAY',
#  'BSH_AWAY',
#  'home_player_X7_AWAY',
#  'home_player_Y1_AWAY',
#  'home_player_11_AWAY',
#  'BSD_AWAY',
#  'home_player_X8_AWAY',
#  'home_player_Y2_AWAY',
#  'away_player_1_AWAY',
#  'BSA_AWAY',
#  'home_player_X9_AWAY',
#  'home_player_Y3_AWAY',
#  'away_player_2_AWAY',
#  'home_player_X10_AWAY',
#  'home_player_Y4_AWAY',
#  'away_player_3_AWAY',
#  'home_player_X11_AWAY',
#  'home_player_Y5_AWAY',
#  'away_player_4_AWAY',
#  'away_player_X1_AWAY',
#  'home_player_Y6_AWAY',
#  'away_player_5_AWAY',
#  'away_player_X2_AWAY',
#  'home_player_Y7_AWAY',
#  'away_player_6_AWAY',
#  'away_player_X3_AWAY',
#  'home_player_Y8_AWAY',
#  'away_player_7_AWAY',
#  'away_player_X4_AWAY',
#  'home_player_Y9_AWAY',
#  'away_player_8_AWAY',
#  'away_player_X5_AWAY',
#  'home_player_Y10_AWAY',
#  'away_player_9_AWAY',
#  'away_player_X6_AWAY',
#  'home_player_Y11_AWAY',
#  'away_player_10_AWAY',
#  'away_player_X7_AWAY',
#  'away_player_Y1_AWAY',
#  'away_player_11_AWAY',
#  'away_player_X8_AWAY',
#  'away_player_Y2_AWAY',
#  'goal_AWAY',
#  'away_player_X9_AWAY',
#  'away_player_Y3_AWAY',
#  'shoton_AWAY',
#  'away_player_X10_AWAY',
#  'away_player_Y4_AWAY',
#  'shotoff_AWAY',
#  'away_player_X11_AWAY',
#  'away_player_Y5_AWAY',
#  'foulcommit_AWAY',
#  'key_0_AWAY',
#  '_sa_instance_state_x_AWAY',
#  'team_short_name_AWAY',
#  'team_fifa_api_id_x_AWAY',
#  'id_x_AWAY',
#  'team_api_id_x_AWAY',
#  'team_long_name_AWAY',
#  '_sa_instance_state_y_AWAY',
#  'chanceCreationPassing_AWAY',
#  'buildUpPlaySpeed_AWAY',
#  'defenceAggression_AWAY',
#  'chanceCreationPassingClass_AWAY',
#  'buildUpPlaySpeedClass_AWAY',
#  'defenceAggressionClass_AWAY',
#  'chanceCreationCrossing_AWAY',
#  'buildUpPlayDribbling_AWAY',
#  'defenceTeamWidth_AWAY',
#  'defencePressureClass_AWAY',
#  'chanceCreationCrossingClass_AWAY',
#  'buildUpPlayDribblingClass_AWAY',
#  'defenceTeamWidthClass_AWAY',
#  'chanceCreationShooting_AWAY',
#  'buildUpPlayPassing_AWAY',
#  'defenceDefenderLineClass_AWAY',
#  'id_y_AWAY',
#  'chanceCreationShootingClass_AWAY',
#  'buildUpPlayPassingClass_AWAY',
#  'chanceCreationPositioningClass_AWAY',
#  'team_fifa_api_id_y_AWAY',
#  'buildUpPlayPositioningClass_AWAY',
#  'team_api_id_y_AWAY',
#  'defencePressure_AWAY',
#  'date_y_AWAY']

# %%
print(match_merged['home_player_3_AWAY'])
match_merged['home_player_3_HOME']
# Out:
# 0         38388.0
# 1         38389.0
# 2         38389.0
# 3         38389.0
# 4         38389.0
#            ...
# 18238     37844.0
# 18239    202663.0
# 18240    202663.0
# 18241    202663.0
# 18242    202663.0
# Name: home_player_3_AWAY, Length: 18243, dtype: float64
# 0         38388.0
# 1         38389.0
# 2         38389.0
# 3         38389.0
# 4         38389.0
#            ...
# 18238     37844.0
# 18239    202663.0
# 18240    202663.0
# 18241    202663.0
# 18242    202663.0
# Name: home_player_3_HOME, Length: 18243, dtype: float64

# %%
listie = match_merged.columns.sort_values(ascending=False).tolist()

# %%
match_cols = df_dict['Match'].columns.sort_values(ascending=False).tolist()

# %%
remove_list = [f"{i}_AWAY" for i in match_cols]

# %%
remove_list
# Out:
# ['stage_AWAY',
#  'shoton_AWAY',
#  'shotoff_AWAY',
#  'season_AWAY',
#  'possession_AWAY',
#  'match_api_id_AWAY',
#  'league_id_AWAY',
#  'id_AWAY',
#  'home_team_goal_AWAY',
#  'home_team_api_id_AWAY',
#  'home_player_Y9_AWAY',
#  'home_player_Y8_AWAY',
#  'home_player_Y7_AWAY',
#  'home_player_Y6_AWAY',
#  'home_player_Y5_AWAY',
#  'home_player_Y4_AWAY',
#  'home_player_Y3_AWAY',
#  'home_player_Y2_AWAY',
#  'home_player_Y11_AWAY',
#  'home_player_Y10_AWAY',
#  'home_player_Y1_AWAY',
#  'home_player_X9_AWAY',
#  'home_player_X8_AWAY',
#  'home_player_X7_AWAY',
#  'home_player_X6_AWAY',
#  'home_player_X5_AWAY',
#  'home_player_X4_AWAY',
#  'home_player_X3_AWAY',
#  'home_player_X2_AWAY',
#  'home_player_X11_AWAY',
#  'home_player_X10_AWAY',
#  'home_player_X1_AWAY',
#  'home_player_9_AWAY',
#  'home_player_8_AWAY',
#  'home_player_7_AWAY',
#  'home_player_6_AWAY',
#  'home_player_5_AWAY',
#  'home_player_4_AWAY',
#  'home_player_3_AWAY',
#  'home_player_2_AWAY',
#  'home_player_11_AWAY',
#  'home_player_10_AWAY',
#  'home_player_1_AWAY',
#  'goal_AWAY',
#  'foulcommit_AWAY',
#  'date_AWAY',
#  'cross_AWAY',
#  'country_id_AWAY',
#  'corner_AWAY',
#  'card_AWAY',
#  'away_team_goal_AWAY',
#  'away_team_api_id_AWAY',
#  'away_player_Y9_AWAY',
#  'away_player_Y8_AWAY',
#  'away_player_Y7_AWAY',
#  'away_player_Y6_AWAY',
#  'away_player_Y5_AWAY',
#  'away_player_Y4_AWAY',
#  'away_player_Y3_AWAY',
#  'away_player_Y2_AWAY',
#  'away_player_Y11_AWAY',
#  'away_player_Y10_AWAY',
#  'away_player_Y1_AWAY',
#  'away_player_X9_AWAY',
#  'away_player_X8_AWAY',
#  'away_player_X7_AWAY',
#  'away_player_X6_AWAY',
#  'away_player_X5_AWAY',
#  'away_player_X4_AWAY',
#  'away_player_X3_AWAY',
#  'away_player_X2_AWAY',
#  'away_player_X11_AWAY',
#  'away_player_X10_AWAY',
#  'away_player_X1_AWAY',
#  'away_player_9_AWAY',
#  'away_player_8_AWAY',
#  'away_player_7_AWAY',
#  'away_player_6_AWAY',
#  'away_player_5_AWAY',
#  'away_player_4_AWAY',
#  'away_player_3_AWAY',
#  'away_player_2_AWAY',
#  'away_player_11_AWAY',
#  'away_player_10_AWAY',
#  'away_player_1_AWAY',
#  '_sa_instance_state_AWAY',
#  'YEAR_AWAY',
#  'WHH_AWAY',
#  'WHD_AWAY',
#  'WHA_AWAY',
#  'VCH_AWAY',
#  'VCD_AWAY',
#  'VCA_AWAY',
#  'SJH_AWAY',
#  'SJD_AWAY',
#  'SJA_AWAY',
#  'PSH_AWAY',
#  'PSD_AWAY',
#  'PSA_AWAY',
#  'LBH_AWAY',
#  'LBD_AWAY',
#  'LBA_AWAY',
#  'IWH_AWAY',
#  'IWD_AWAY',
#  'IWA_AWAY',
#  'GBH_AWAY',
#  'GBD_AWAY',
#  'GBA_AWAY',
#  'BWH_AWAY',
#  'BWD_AWAY',
#  'BWA_AWAY',
#  'BSH_AWAY',
#  'BSD_AWAY',
#  'BSA_AWAY',
#  'B365H_AWAY',
#  'B365D_AWAY',
#  'B365A_AWAY']

# %%
remove_list = ['stage_AWAY',
 'shoton_AWAY',
 'shotoff_AWAY',
 'season_AWAY',
 'possession_AWAY',
 'match_api_id_AWAY',
 'league_id_AWAY',
 'home_team_goal_AWAY',
 'home_team_api_id_AWAY',
 'home_player_Y9_AWAY',
 'home_player_Y8_AWAY',
 'home_player_Y7_AWAY',
 'home_player_Y6_AWAY',
 'home_player_Y5_AWAY',
 'home_player_Y4_AWAY',
 'home_player_Y3_AWAY',
 'home_player_Y2_AWAY',
 'home_player_Y11_AWAY',
 'home_player_Y10_AWAY',
 'home_player_Y1_AWAY',
 'home_player_X9_AWAY',
 'home_player_X8_AWAY',
 'home_player_X7_AWAY',
 'home_player_X6_AWAY',
 'home_player_X5_AWAY',
 'home_player_X4_AWAY',
 'home_player_X3_AWAY',
 'home_player_X2_AWAY',
 'home_player_X11_AWAY',
 'home_player_X10_AWAY',
 'home_player_X1_AWAY',
 'home_player_9_AWAY',
 'home_player_8_AWAY',
 'home_player_7_AWAY',
 'home_player_6_AWAY',
 'home_player_5_AWAY',
 'home_player_4_AWAY',
 'home_player_3_AWAY',
 'home_player_2_AWAY',
 'home_player_11_AWAY',
 'home_player_10_AWAY',
 'home_player_1_AWAY',
 'goal_AWAY',
 'foulcommit_AWAY',
 'cross_AWAY',
 'country_id_AWAY',
 'corner_AWAY',
 'card_AWAY',
 'away_team_goal_AWAY',
 'away_team_api_id_AWAY',
 'away_player_Y9_AWAY',
 'away_player_Y8_AWAY',
 'away_player_Y7_AWAY',
 'away_player_Y6_AWAY',
 'away_player_Y5_AWAY',
 'away_player_Y4_AWAY',
 'away_player_Y3_AWAY',
 'away_player_Y2_AWAY',
 'away_player_Y11_AWAY',
 'away_player_Y10_AWAY',
 'away_player_Y1_AWAY',
 'away_player_X9_AWAY',
 'away_player_X8_AWAY',
 'away_player_X7_AWAY',
 'away_player_X6_AWAY',
 'away_player_X5_AWAY',
 'away_player_X4_AWAY',
 'away_player_X3_AWAY',
 'away_player_X2_AWAY',
 'away_player_X11_AWAY',
 'away_player_X10_AWAY',
 'away_player_X1_AWAY',
 'away_player_9_AWAY',
 'away_player_8_AWAY',
 'away_player_7_AWAY',
 'away_player_6_AWAY',
 'away_player_5_AWAY',
 'away_player_4_AWAY',
 'away_player_3_AWAY',
 'away_player_2_AWAY',
 'away_player_11_AWAY',
 'away_player_10_AWAY',
 'away_player_1_AWAY',
 '_sa_instance_state_AWAY',
 'WHH_AWAY',
 'WHD_AWAY',
 'WHA_AWAY',
 'VCH_AWAY',
 'VCD_AWAY',
 'VCA_AWAY',
 'SJH_AWAY',
 'SJD_AWAY',
 'SJA_AWAY',
 'PSH_AWAY',
 'PSD_AWAY',
 'PSA_AWAY',
 'LBH_AWAY',
 'LBD_AWAY',
 'LBA_AWAY',
 'IWH_AWAY',
 'IWD_AWAY',
 'IWA_AWAY',
 'GBH_AWAY',
 'GBD_AWAY',
 'GBA_AWAY',
 'BWH_AWAY',
 'BWD_AWAY',
 'BWA_AWAY',
 'BSH_AWAY',
 'BSD_AWAY',
 'BSA_AWAY',
 'B365H_AWAY',
 'B365D_AWAY',
 'B365A_AWAY']

# %%
match_merged.drop(columns=remove_list,inplace=True)

# %%
match_cols
# Out:
# ['stage',
#  'shoton',
#  'shotoff',
#  'season',
#  'possession',
#  'match_api_id',
#  'league_id',
#  'id',
#  'home_team_goal',
#  'home_team_api_id',
#  'home_player_Y9',
#  'home_player_Y8',
#  'home_player_Y7',
#  'home_player_Y6',
#  'home_player_Y5',
#  'home_player_Y4',
#  'home_player_Y3',
#  'home_player_Y2',
#  'home_player_Y11',
#  'home_player_Y10',
#  'home_player_Y1',
#  'home_player_X9',
#  'home_player_X8',
#  'home_player_X7',
#  'home_player_X6',
#  'home_player_X5',
#  'home_player_X4',
#  'home_player_X3',
#  'home_player_X2',
#  'home_player_X11',
#  'home_player_X10',
#  'home_player_X1',
#  'home_player_9',
#  'home_player_8',
#  'home_player_7',
#  'home_player_6',
#  'home_player_5',
#  'home_player_4',
#  'home_player_3',
#  'home_player_2',
#  'home_player_11',
#  'home_player_10',
#  'home_player_1',
#  'goal',
#  'foulcommit',
#  'date',
#  'cross',
#  'country_id',
#  'corner',
#  'card',
#  'away_team_goal',
#  'away_team_api_id',
#  'away_player_Y9',
#  'away_player_Y8',
#  'away_player_Y7',
#  'away_player_Y6',
#  'away_player_Y5',
#  'away_player_Y4',
#  'away_player_Y3',
#  'away_player_Y2',
#  'away_player_Y11',
#  'away_player_Y10',
#  'away_player_Y1',
#  'away_player_X9',
#  'away_player_X8',
#  'away_player_X7',
#  'away_player_X6',
#  'away_player_X5',
#  'away_player_X4',
#  'away_player_X3',
#  'away_player_X2',
#  'away_player_X11',
#  'away_player_X10',
#  'away_player_X1',
#  'away_player_9',
#  'away_player_8',
#  'away_player_7',
#  'away_player_6',
#  'away_player_5',
#  'away_player_4',
#  'away_player_3',
#  'away_player_2',
#  'away_player_11',
#  'away_player_10',
#  'away_player_1',
#  '_sa_instance_state',
#  'YEAR',
#  'WHH',
#  'WHD',
#  'WHA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'SJH',
#  'SJD',
#  'SJA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'LBH',
#  'LBD',
#  'LBA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'GBH',
#  'GBD',
#  'GBA',
#  'BWH',
#  'BWD',
#  'BWA',
#  'BSH',
#  'BSD',
#  'BSA',
#  'B365H',
#  'B365D',
#  'B365A']

# %%
remove_home_list = ['stage_HOME',
 'shoton_HOME',
 'shotoff_HOME',
 'season_HOME',
 'possession_HOME',
 'match_api_id_HOME',
 'league_id_HOME',
 'home_team_goal_HOME',
 'home_team_api_id_HOME',
 'home_player_Y9_HOME',
 'home_player_Y8_HOME',
 'home_player_Y7_HOME',
 'home_player_Y6_HOME',
 'home_player_Y5_HOME',
 'home_player_Y4_HOME',
 'home_player_Y3_HOME',
 'home_player_Y2_HOME',
 'home_player_Y11_HOME',
 'home_player_Y10_HOME',
 'home_player_Y1_HOME',
 'home_player_X9_HOME',
 'home_player_X8_HOME',
 'home_player_X7_HOME',
 'home_player_X6_HOME',
 'home_player_X5_HOME',
 'home_player_X4_HOME',
 'home_player_X3_HOME',
 'home_player_X2_HOME',
 'home_player_X11_HOME',
 'home_player_X10_HOME',
 'home_player_X1_HOME',
 'home_player_9_HOME',
 'home_player_8_HOME',
 'home_player_7_HOME',
 'home_player_6_HOME',
 'home_player_5_HOME',
 'home_player_4_HOME',
 'home_player_3_HOME',
 'home_player_2_HOME',
 'home_player_11_HOME',
 'home_player_10_HOME',
 'home_player_1_HOME',
 'goal_HOME',
 'foulcommit_HOME',
 'cross_HOME',
 'country_id_HOME',
 'corner_HOME',
 'card_HOME',
 'away_team_goal_HOME',
 'away_team_api_id_HOME',
 'away_player_Y9_HOME',
 'away_player_Y8_HOME',
 'away_player_Y7_HOME',
 'away_player_Y6_HOME',
 'away_player_Y5_HOME',
 'away_player_Y4_HOME',
 'away_player_Y3_HOME',
 'away_player_Y2_HOME',
 'away_player_Y11_HOME',
 'away_player_Y10_HOME',
 'away_player_Y1_HOME',
 'away_player_X9_HOME',
 'away_player_X8_HOME',
 'away_player_X7_HOME',
 'away_player_X6_HOME',
 'away_player_X5_HOME',
 'away_player_X4_HOME',
 'away_player_X3_HOME',
 'away_player_X2_HOME',
 'away_player_X11_HOME',
 'away_player_X10_HOME',
 'away_player_X1_HOME',
 'away_player_9_HOME',
 'away_player_8_HOME',
 'away_player_7_HOME',
 'away_player_6_HOME',
 'away_player_5_HOME',
 'away_player_4_HOME',
 'away_player_3_HOME',
 'away_player_2_HOME',
 'away_player_11_HOME',
 'away_player_10_HOME',
 'away_player_1_HOME',
 '_sa_instance_state_HOME',
 'WHH_HOME',
 'WHD_HOME',
 'WHA_HOME',
 'VCH_HOME',
 'VCD_HOME',
 'VCA_HOME',
 'SJH_HOME',
 'SJD_HOME',
 'SJA_HOME',
 'PSH_HOME',
 'PSD_HOME',
 'PSA_HOME',
 'LBH_HOME',
 'LBD_HOME',
 'LBA_HOME',
 'IWH_HOME',
 'IWD_HOME',
 'IWA_HOME',
 'GBH_HOME',
 'GBD_HOME',
 'GBA_HOME',
 'BWH_HOME',
 'BWD_HOME',
 'BWA_HOME',
 'BSH_HOME',
 'BSD_HOME',
 'BSA_HOME',
 'B365H_HOME',
 'B365D_HOME',
 'B365A_HOME']

# %%
transposed = match_merged.T

# %%
df = transposed.drop_duplicates().T

# %%
df.columns.tolist()
# Out:
# ['_sa_instance_state_HOME',
#  'country_id_HOME',
#  'away_player_Y6_HOME',
#  'card_HOME',
#  'PSH_HOME',
#  'away_player_Y7_HOME',
#  'cross_HOME',
#  'PSD_HOME',
#  'season_HOME',
#  'away_player_Y8_HOME',
#  'corner_HOME',
#  'PSA_HOME',
#  'stage_HOME',
#  'away_player_Y9_HOME',
#  'possession_HOME',
#  'WHH_HOME',
#  'date_x_HOME',
#  'away_player_Y10_HOME',
#  'B365H_HOME',
#  'WHD_HOME',
#  'match_api_id_HOME',
#  'away_player_Y11_HOME',
#  'B365D_HOME',
#  'WHA_HOME',
#  'home_team_api_id_HOME',
#  'home_player_1_HOME',
#  'B365A_HOME',
#  'SJH_HOME',
#  'away_team_api_id_HOME',
#  'home_player_2_HOME',
#  'BWH_HOME',
#  'SJD_HOME',
#  'home_player_3_HOME',
#  'home_team_goal_HOME',
#  'BWD_HOME',
#  'SJA_HOME',
#  'away_team_goal_HOME',
#  'home_player_4_HOME',
#  'BWA_HOME',
#  'VCH_HOME',
#  'home_player_X1_HOME',
#  'home_player_5_HOME',
#  'IWH_HOME',
#  'VCD_HOME',
#  'home_player_X2_HOME',
#  'home_player_6_HOME',
#  'IWD_HOME',
#  'VCA_HOME',
#  'home_player_X3_HOME',
#  'home_player_7_HOME',
#  'IWA_HOME',
#  'GBH_HOME',
#  'home_player_X4_HOME',
#  'home_player_8_HOME',
#  'LBH_HOME',
#  'GBD_HOME',
#  'home_player_X5_HOME',
#  'home_player_9_HOME',
#  'LBD_HOME',
#  'GBA_HOME',
#  'home_player_X6_HOME',
#  'home_player_10_HOME',
#  'LBA_HOME',
#  'BSH_HOME',
#  'home_player_X7_HOME',
#  'home_player_Y1_HOME',
#  'home_player_11_HOME',
#  'BSD_HOME',
#  'home_player_X8_HOME',
#  'home_player_Y2_HOME',
#  'away_player_1_HOME',
#  'BSA_HOME',
#  'home_player_X9_HOME',
#  'home_player_Y3_HOME',
#  'away_player_2_HOME',
#  'home_player_X10_HOME',
#  'home_player_Y4_HOME',
#  'away_player_3_HOME',
#  'home_player_X11_HOME',
#  'home_player_Y5_HOME',
#  'away_player_4_HOME',
#  'away_player_X1_HOME',
#  'home_player_Y6_HOME',
#  'away_player_5_HOME',
#  'away_player_X2_HOME',
#  'home_player_Y7_HOME',
#  'away_player_6_HOME',
#  'away_player_X3_HOME',
#  'home_player_Y8_HOME',
#  'away_player_7_HOME',
#  'away_player_X4_HOME',
#  'home_player_Y9_HOME',
#  'away_player_8_HOME',
#  'away_player_X5_HOME',
#  'home_player_Y10_HOME',
#  'away_player_9_HOME',
#  'away_player_X6_HOME',
#  'home_player_Y11_HOME',
#  'away_player_10_HOME',
#  'away_player_X7_HOME',
#  'away_player_Y1_HOME',
#  'away_player_11_HOME',
#  'away_player_X8_HOME',
#  'goal_HOME',
#  'away_player_X9_HOME',
#  'shoton_HOME',
#  'away_player_X10_HOME',
#  'away_player_Y4_HOME',
#  'shotoff_HOME',
#  'id',
#  'away_player_X11_HOME',
#  'away_player_Y5_HOME',
#  'foulcommit_HOME',
#  'YEAR',
#  '_sa_instance_state_x_HOME',
#  'team_short_name_HOME',
#  'team_fifa_api_id_x_HOME',
#  'id_x_HOME',
#  'team_long_name_HOME',
#  '_sa_instance_state_y_HOME',
#  'chanceCreationPassing_HOME',
#  'buildUpPlaySpeed_HOME',
#  'defenceAggression_HOME',
#  'chanceCreationPassingClass_HOME',
#  'buildUpPlaySpeedClass_HOME',
#  'defenceAggressionClass_HOME',
#  'chanceCreationCrossing_HOME',
#  'buildUpPlayDribbling_HOME',
#  'defenceTeamWidth_HOME',
#  'defencePressureClass_HOME',
#  'chanceCreationCrossingClass_HOME',
#  'buildUpPlayDribblingClass_HOME',
#  'defenceTeamWidthClass_HOME',
#  'chanceCreationShooting_HOME',
#  'buildUpPlayPassing_HOME',
#  'defenceDefenderLineClass_HOME',
#  'id_y_HOME',
#  'chanceCreationShootingClass_HOME',
#  'buildUpPlayPassingClass_HOME',
#  'chanceCreationPositioningClass_HOME',
#  'buildUpPlayPositioningClass_HOME',
#  'defencePressure_HOME',
#  'date_y_HOME',
#  '_sa_instance_state_x_AWAY',
#  'team_short_name_AWAY',
#  'team_fifa_api_id_x_AWAY',
#  'id_x_AWAY',
#  'team_long_name_AWAY',
#  '_sa_instance_state_y_AWAY',
#  'chanceCreationPassing_AWAY',
#  'buildUpPlaySpeed_AWAY',
#  'defenceAggression_AWAY',
#  'chanceCreationPassingClass_AWAY',
#  'buildUpPlaySpeedClass_AWAY',
#  'defenceAggressionClass_AWAY',
#  'chanceCreationCrossing_AWAY',
#  'buildUpPlayDribbling_AWAY',
#  'defenceTeamWidth_AWAY',
#  'defencePressureClass_AWAY',
#  'chanceCreationCrossingClass_AWAY',
#  'buildUpPlayDribblingClass_AWAY',
#  'defenceTeamWidthClass_AWAY',
#  'chanceCreationShooting_AWAY',
#  'buildUpPlayPassing_AWAY',
#  'defenceDefenderLineClass_AWAY',
#  'id_y_AWAY',
#  'chanceCreationShootingClass_AWAY',
#  'buildUpPlayPassingClass_AWAY',
#  'chanceCreationPositioningClass_AWAY',
#  'buildUpPlayPositioningClass_AWAY',
#  'defencePressure_AWAY']

# %%
transposed = player_merged.T
player_merged = transposed.drop_duplicates().T

# %%
player_merged.columns.to_list()
# Out:
# ['key_0',
#  '_sa_instance_state_x',
#  'weight',
#  'birthday',
#  'player_name',
#  'height',
#  'player_fifa_api_id_x',
#  'id_x',
#  '_sa_instance_state_y',
#  'heading_accuracy',
#  'strength',
#  'overall_rating',
#  'sprint_speed',
#  'sliding_tackle',
#  'short_passing',
#  'long_shots',
#  'potential',
#  'agility',
#  'gk_diving',
#  'acceleration',
#  'volleys',
#  'aggression',
#  'preferred_foot',
#  'reactions',
#  'gk_handling',
#  'dribbling',
#  'interceptions',
#  'attacking_work_rate',
#  'balance',
#  'standing_tackle',
#  'gk_kicking',
#  'curve',
#  'positioning',
#  'defensive_work_rate',
#  'shot_power',
#  'gk_positioning',
#  'id_y',
#  'free_kick_accuracy',
#  'vision',
#  'crossing',
#  'jumping',
#  'gk_reflexes',
#  'long_passing',
#  'player_fifa_api_id_y',
#  'penalties',
#  'finishing',
#  'stamina',
#  'ball_control',
#  'marking',
#  'date']

# %%
for i in transposed.index:
    if i not in player_merged.columns.to_list():
        print(i)
# Out:
# player_api_id_x
# player_api_id_y
