# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pandas as pd

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///C:/Users/JoshWeidenaar/Downloads/database.sqlite")

# %%
engine
# Out:
# Engine(sqlite:///C:/Users/JoshWeidenaar/Downloads/database.sqlite)

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# Create a session
session = Session(engine)

# %%
# Print all of the classes mapped to the Base
classes = Base.classes.keys()

# %%
df_dict = {}

for i in classes:
    class_call = Base.classes[i]
    class_data = session.query(class_call).all()
    listie_dicts = []
    for j in class_data:
        listie_dicts.append(j.__dict__)
    df_dict[i] = pd.DataFrame(listie_dicts)
# Out:
# C:\Users\JoshWeidenaar\anaconda3\lib\site-packages\sqlalchemy\sql\sqltypes.py:661: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   util.warn(

# %%
classes
# Out:
# ['Country',
#  'League',
#  'country',
#  'Match',
#  'Player',
#  'Team',
#  'Player_Attributes',
#  'Team_Attributes']

# %%
country_id = df_dict['country']['id']
country_id_LEAGUE = df_dict['League']['country_id']
league_id = df_dict['League']['id']

# %%
league_id_MATCH = df_dict['Match']['league_id']
country_id_MATCH = df_dict['Match']['country_id']
home_team_api_id_MATCH = df_dict['Match']['home_team_api_id']
away_team_api_id_MATCH = df_dict['Match']['away_team_api_id'] 
player_id_MATCH = []#any attr in Match table that has the word "player" in it
player_id = df_dict['Player']['id']
player_api_id = df_dict['Player']['player_api_id']
player_fifa_id = df_dict['Player']['player_fifa_api_id']
player_attr_id = df_dict['Player_Attributes']['id']
player_id_ATTRS = df_dict['Player_Attributes']['player_api_id']
player_fifa_id_ATTRS = df_dict['Player_Attributes']['player_fifa_api_id']
team_fifa_id = df_dict['Team']['team_fifa_api_id']
team_id = df_dict['Team']['id']
team_api_id = df_dict['Team']['team_api_id']
team_id_ATTRS = df_dict['Team_Attributes']['team_api_id']
team_fifa_id_ATTRS = df_dict['Team_Attributes']['team_fifa_api_id']

# %%
player_merged = pd.merge(df_dict['Player'],df_dict['Player_Attributes'],left_on=player_api_id,right_on=player_id_ATTRS)
print(len(df_dict['Player_Attributes']) - len(player_merged))
# Out:
# 0

# %%
team_merged = pd.merge(df_dict['Team'],df_dict['Team_Attributes'],left_on=team_api_id ,right_on=team_id_ATTRS)
print(len(df_dict['Team_Attributes']) - len(team_merged))
# Out:
# 0

# %%
league_merged = pd.merge(df_dict['League'],df_dict['Country'],left_on=country_id_LEAGUE,right_on=country_id)
print(len(df_dict['League']) - len(league_merged))
# Out:
# 0

# %%
sqlite_ddl = """CREATE TABLE "Country" (
	"id"	INTEGER,
	"name"	TEXT UNIQUE,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "League" (
	"id"	INTEGER,
	"country_id"	INTEGER,
	"name"	TEXT UNIQUE,
	FOREIGN KEY("country_id") REFERENCES "country"("id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Match" (
	"id"	INTEGER,
	"country_id"	INTEGER,
	"league_id"	INTEGER,
	"season"	TEXT,
	"stage"	INTEGER,
	"date"	TEXT,
	"match_api_id"	INTEGER UNIQUE,
	"home_team_api_id"	INTEGER,
	"away_team_api_id"	INTEGER,
	"home_team_goal"	INTEGER,
	"away_team_goal"	INTEGER,
	"home_player_X1"	INTEGER,
	"home_player_X2"	INTEGER,
	"home_player_X3"	INTEGER,
	"home_player_X4"	INTEGER,
	"home_player_X5"	INTEGER,
	"home_player_X6"	INTEGER,
	"home_player_X7"	INTEGER,
	"home_player_X8"	INTEGER,
	"home_player_X9"	INTEGER,
	"home_player_X10"	INTEGER,
	"home_player_X11"	INTEGER,
	"away_player_X1"	INTEGER,
	"away_player_X2"	INTEGER,
	"away_player_X3"	INTEGER,
	"away_player_X4"	INTEGER,
	"away_player_X5"	INTEGER,
	"away_player_X6"	INTEGER,
	"away_player_X7"	INTEGER,
	"away_player_X8"	INTEGER,
	"away_player_X9"	INTEGER,
	"away_player_X10"	INTEGER,
	"away_player_X11"	INTEGER,
	"home_player_Y1"	INTEGER,
	"home_player_Y2"	INTEGER,
	"home_player_Y3"	INTEGER,
	"home_player_Y4"	INTEGER,
	"home_player_Y5"	INTEGER,
	"home_player_Y6"	INTEGER,
	"home_player_Y7"	INTEGER,
	"home_player_Y8"	INTEGER,
	"home_player_Y9"	INTEGER,
	"home_player_Y10"	INTEGER,
	"home_player_Y11"	INTEGER,
	"away_player_Y1"	INTEGER,
	"away_player_Y2"	INTEGER,
	"away_player_Y3"	INTEGER,
	"away_player_Y4"	INTEGER,
	"away_player_Y5"	INTEGER,
	"away_player_Y6"	INTEGER,
	"away_player_Y7"	INTEGER,
	"away_player_Y8"	INTEGER,
	"away_player_Y9"	INTEGER,
	"away_player_Y10"	INTEGER,
	"away_player_Y11"	INTEGER,
	"home_player_1"	INTEGER,
	"home_player_2"	INTEGER,
	"home_player_3"	INTEGER,
	"home_player_4"	INTEGER,
	"home_player_5"	INTEGER,
	"home_player_6"	INTEGER,
	"home_player_7"	INTEGER,
	"home_player_8"	INTEGER,
	"home_player_9"	INTEGER,
	"home_player_10"	INTEGER,
	"home_player_11"	INTEGER,
	"away_player_1"	INTEGER,
	"away_player_2"	INTEGER,
	"away_player_3"	INTEGER,
	"away_player_4"	INTEGER,
	"away_player_5"	INTEGER,
	"away_player_6"	INTEGER,
	"away_player_7"	INTEGER,
	"away_player_8"	INTEGER,
	"away_player_9"	INTEGER,
	"away_player_10"	INTEGER,
	"away_player_11"	INTEGER,
	"goal"	TEXT,
	"shoton"	TEXT,
	"shotoff"	TEXT,
	"foulcommit"	TEXT,
	"card"	TEXT,
	"cross"	TEXT,
	"corner"	TEXT,
	"possession"	TEXT,
	"B365H"	NUMERIC,
	"B365D"	NUMERIC,
	"B365A"	NUMERIC,
	"BWH"	NUMERIC,
	"BWD"	NUMERIC,
	"BWA"	NUMERIC,
	"IWH"	NUMERIC,
	"IWD"	NUMERIC,
	"IWA"	NUMERIC,
	"LBH"	NUMERIC,
	"LBD"	NUMERIC,
	"LBA"	NUMERIC,
	"PSH"	NUMERIC,
	"PSD"	NUMERIC,
	"PSA"	NUMERIC,
	"WHH"	NUMERIC,
	"WHD"	NUMERIC,
	"WHA"	NUMERIC,
	"SJH"	NUMERIC,
	"SJD"	NUMERIC,
	"SJA"	NUMERIC,
	"VCH"	NUMERIC,
	"VCD"	NUMERIC,
	"VCA"	NUMERIC,
	"GBH"	NUMERIC,
	"GBD"	NUMERIC,
	"GBA"	NUMERIC,
	"BSH"	NUMERIC,
	"BSD"	NUMERIC,
	"BSA"	NUMERIC,
	FOREIGN KEY("home_player_9") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_1") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_10") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_2") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_3") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_4") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_5") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_6") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_11") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_5") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_7") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_4") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_9") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_10") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_7") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_6") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_8") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_8") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_team_api_id") REFERENCES "Team"("team_api_id"),
	FOREIGN KEY("home_player_1") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_3") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_2") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("country_id") REFERENCES "country"("id"),
	FOREIGN KEY("league_id") REFERENCES "League"("id"),
	FOREIGN KEY("home_team_api_id") REFERENCES "Team"("team_api_id"),
	FOREIGN KEY("away_player_11") REFERENCES "Player"("player_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Player" (
	"id"	INTEGER,
	"player_api_id"	INTEGER UNIQUE,
	"player_name"	TEXT,
	"player_fifa_api_id"	INTEGER UNIQUE,
	"birthday"	TEXT,
	"height"	INTEGER,
	"weight"	INTEGER,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
​
CREATE TABLE "Player_Attributes" (
	"id"	INTEGER,
	"player_fifa_api_id"	INTEGER,
	"player_api_id"	INTEGER,
	"date"	TEXT,
	"overall_rating"	INTEGER,
	"potential"	INTEGER,
	"preferred_foot"	TEXT,
	"attacking_work_rate"	TEXT,
	"defensive_work_rate"	TEXT,
	"crossing"	INTEGER,
	"finishing"	INTEGER,
	"heading_accuracy"	INTEGER,
	"short_passing"	INTEGER,
	"volleys"	INTEGER,
	"dribbling"	INTEGER,
	"curve"	INTEGER,
	"free_kick_accuracy"	INTEGER,
	"long_passing"	INTEGER,
	"ball_control"	INTEGER,
	"acceleration"	INTEGER,
	"sprint_speed"	INTEGER,
	"agility"	INTEGER,
	"reactions"	INTEGER,
	"balance"	INTEGER,
	"shot_power"	INTEGER,
	"jumping"	INTEGER,
	"stamina"	INTEGER,
	"strength"	INTEGER,
	"long_shots"	INTEGER,
	"aggression"	INTEGER,
	"interceptions"	INTEGER,
	"positioning"	INTEGER,
	"vision"	INTEGER,
	"penalties"	INTEGER,
	"marking"	INTEGER,
	"standing_tackle"	INTEGER,
	"sliding_tackle"	INTEGER,
	"gk_diving"	INTEGER,
	"gk_handling"	INTEGER,
	"gk_kicking"	INTEGER,
	"gk_positioning"	INTEGER,
	"gk_reflexes"	INTEGER,
	FOREIGN KEY("player_fifa_api_id") REFERENCES "Player"("player_fifa_api_id"),
	FOREIGN KEY("player_api_id") REFERENCES "Player"("player_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Team" (
	"id"	INTEGER,
	"team_api_id"	INTEGER UNIQUE,
	"team_fifa_api_id"	INTEGER,
	"team_long_name"	TEXT,
	"team_short_name"	TEXT,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Team_Attributes" (
	"id"	INTEGER,
	"team_fifa_api_id"	INTEGER,
	"team_api_id"	INTEGER,
	"date"	TEXT,
	"buildUpPlaySpeed"	INTEGER,
	"buildUpPlaySpeedClass"	TEXT,
	"buildUpPlayDribbling"	INTEGER,
	"buildUpPlayDribblingClass"	TEXT,
	"buildUpPlayPassing"	INTEGER,
	"buildUpPlayPassingClass"	TEXT,
	"buildUpPlayPositioningClass"	TEXT,
	"chanceCreationPassing"	INTEGER,
	"chanceCreationPassingClass"	TEXT,
	"chanceCreationCrossing"	INTEGER,
	"chanceCreationCrossingClass"	TEXT,
	"chanceCreationShooting"	INTEGER,
	"chanceCreationShootingClass"	TEXT,
	"chanceCreationPositioningClass"	TEXT,
	"defencePressure"	INTEGER,
	"defencePressureClass"	TEXT,
	"defenceAggression"	INTEGER,
	"defenceAggressionClass"	TEXT,
	"defenceTeamWidth"	INTEGER,
	"defenceTeamWidthClass"	TEXT,
	"defenceDefenderLineClass"	TEXT,
	FOREIGN KEY("team_fifa_api_id") REFERENCES "Team"("team_fifa_api_id"),
	FOREIGN KEY("team_api_id") REFERENCES "Team"("team_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "sqlite_sequence" (
	"name"	,
	"seq"
);"""

# %%
import datetime as dt

# %%
team_merged['YEAR'] = [dt.date(int(i.split('-')[0]),1,1) for i in team_merged.date]

# %%
df_dict['Match']['YEAR'] = [dt.date(int(i.split('-')[0]),1,1) for i in df_dict['Match'].date]

# %%
merge_team_away = pd.merge(df_dict['Match'],team_merged,left_on=[away_team_api_id_MATCH,'YEAR'],right_on=['team_api_id_x','YEAR'])

# %%
merge_team_home = pd.merge(df_dict['Match'],team_merged,left_on=[home_team_api_id_MATCH,'YEAR'],right_on=['team_api_id_x','YEAR'])

# %%
match_merged = pd.merge(merge_team_home,merge_team_away,left_on=['id','YEAR'],right_on=['id','YEAR'],suffixes=('_HOME','_AWAY'))
len(match_merged)
# Out:
# 18243

# %%
match_merged
# Out:
#                                     _sa_instance_state_x  home_player_4_x  \
# 0      <sqlalchemy.orm.state.InstanceState object at ...          38389.0
# 1      <sqlalchemy.orm.state.InstanceState object at ...          38393.0
# 2      <sqlalchemy.orm.state.InstanceState object at ...          38253.0
# 3      <sqlalchemy.orm.state.InstanceState object at ...          69713.0
# 4      <sqlalchemy.orm.state.InstanceState object at ...          38253.0
# ...                                                  ...              ...
# 18238  <sqlalchemy.orm.state.InstanceState object at ...          32597.0
# 18239  <sqlalchemy.orm.state.InstanceState object at ...          32597.0
# 18240  <sqlalchemy.orm.state.InstanceState object at ...          32597.0
# 18241  <sqlalchemy.orm.state.InstanceState object at ...          32597.0
# 18242  <sqlalchemy.orm.state.InstanceState object at ...          32597.0
#
#                BWA_x         VCH_x  home_player_5_x         IWH_x  \
# ...

# %%
match_merged.columns.tolist()
# Out:
# ['_sa_instance_state_HOME',
#  'home_player_4_HOME',
#  'BWA_HOME',
#  'VCH_HOME',
#  'home_player_5_HOME',
#  'IWH_HOME',
#  'VCD_HOME',
#  'home_player_6_HOME',
#  'IWD_HOME',
#  'VCA_HOME',
#  'home_player_7_HOME',
#  'IWA_HOME',
#  'GBH_HOME',
#  'home_player_8_HOME',
#  'LBH_HOME',
#  'GBD_HOME',
#  'home_player_9_HOME',
#  'LBD_HOME',
#  'GBA_HOME',
#  'id',
#  'home_player_10_HOME',
#  'LBA_HOME',
#  'BSH_HOME',
#  'country_id_HOME',
#  'home_player_11_HOME',
#  'PSH_HOME',
#  'BSD_HOME',
#  'away_player_1_HOME',
#  'league_id_HOME',
#  'PSD_HOME',
#  'BSA_HOME',
#  'season_HOME',
#  'away_player_2_HOME',
#  'PSA_HOME',
#  'stage_HOME',
#  'away_player_3_HOME',
#  'WHH_HOME',
#  'date_x_HOME',
#  'away_player_4_HOME',
#  'WHD_HOME',
#  'match_api_id_HOME',
#  'away_player_5_HOME',
#  'WHA_HOME',
#  'home_team_api_id_HOME',
#  'away_player_6_HOME',
#  'SJH_HOME',
#  'away_team_api_id_HOME',
#  'away_player_7_HOME',
#  'SJD_HOME',
#  'home_team_goal_HOME',
# ...

# %%
print(match_merged['home_player_3_AWAY'])
match_merged['home_player_3_HOME']
# Out:
# 0         38388.0
# 1         38389.0
# 2         38389.0
# 3         38389.0
# 4         38389.0
#            ...
# 18238     37844.0
# 18239    202663.0
# 18240    202663.0
# 18241    202663.0
# 18242    202663.0
# Name: home_player_3_AWAY, Length: 18243, dtype: float64
# 0         38388.0
# 1         38389.0
# 2         38389.0
# 3         38389.0
# 4         38389.0
#            ...
# 18238     37844.0
# 18239    202663.0
# 18240    202663.0
# 18241    202663.0
# 18242    202663.0
# Name: home_player_3_HOME, Length: 18243, dtype: float64

# %%
listie = match_merged.columns.sort_values(ascending=False).tolist()

# %%
match_cols = df_dict['Match'].columns.sort_values(ascending=False).tolist()

# %%
remove_list = [f"{i}_AWAY" for i in match_cols]

# %%
match_merged.drop(columns=remove_list,inplace=True)

# %%
remove_list = ['stage_AWAY',
 'shoton_AWAY',
 'shotoff_AWAY',
 'season_AWAY',
 'possession_AWAY',
 'match_api_id_AWAY',
 'league_id_AWAY',
 'home_team_goal_AWAY',
 'home_team_api_id_AWAY',
 'home_player_Y9_AWAY',
 'home_player_Y8_AWAY',
 'home_player_Y7_AWAY',
 'home_player_Y6_AWAY',
 'home_player_Y5_AWAY',
 'home_player_Y4_AWAY',
 'home_player_Y3_AWAY',
 'home_player_Y2_AWAY',
 'home_player_Y11_AWAY',
 'home_player_Y10_AWAY',
 'home_player_Y1_AWAY',
 'home_player_X9_AWAY',
 'home_player_X8_AWAY',
 'home_player_X7_AWAY',
 'home_player_X6_AWAY',
 'home_player_X5_AWAY',
 'home_player_X4_AWAY',
 'home_player_X3_AWAY',
 'home_player_X2_AWAY',
 'home_player_X11_AWAY',
 'home_player_X10_AWAY',
 'home_player_X1_AWAY',
 'home_player_9_AWAY',
 'home_player_8_AWAY',
 'home_player_7_AWAY',
 'home_player_6_AWAY',
 'home_player_5_AWAY',
 'home_player_4_AWAY',
 'home_player_3_AWAY',
 'home_player_2_AWAY',
 'home_player_11_AWAY',
 'home_player_10_AWAY',
 'home_player_1_AWAY',
 'goal_AWAY',
 'foulcommit_AWAY',
 'cross_AWAY',
 'country_id_AWAY',
 'corner_AWAY',
 'card_AWAY',
 'away_team_goal_AWAY',
 'away_team_api_id_AWAY',
 'away_player_Y9_AWAY',
 'away_player_Y8_AWAY',
 'away_player_Y7_AWAY',
 'away_player_Y6_AWAY',
 'away_player_Y5_AWAY',
 'away_player_Y4_AWAY',
 'away_player_Y3_AWAY',
 'away_player_Y2_AWAY',
 'away_player_Y11_AWAY',
 'away_player_Y10_AWAY',
 'away_player_Y1_AWAY',
 'away_player_X9_AWAY',
 'away_player_X8_AWAY',
 'away_player_X7_AWAY',
 'away_player_X6_AWAY',
 'away_player_X5_AWAY',
 'away_player_X4_AWAY',
 'away_player_X3_AWAY',
 'away_player_X2_AWAY',
 'away_player_X11_AWAY',
 'away_player_X10_AWAY',
 'away_player_X1_AWAY',
 'away_player_9_AWAY',
 'away_player_8_AWAY',
 'away_player_7_AWAY',
 'away_player_6_AWAY',
 'away_player_5_AWAY',
 'away_player_4_AWAY',
 'away_player_3_AWAY',
 'away_player_2_AWAY',
 'away_player_11_AWAY',
 'away_player_10_AWAY',
 'away_player_1_AWAY',
 '_sa_instance_state_AWAY',
 'WHH_AWAY',
 'WHD_AWAY',
 'WHA_AWAY',
 'VCH_AWAY',
 'VCD_AWAY',
 'VCA_AWAY',
 'SJH_AWAY',
 'SJD_AWAY',
 'SJA_AWAY',
 'PSH_AWAY',
 'PSD_AWAY',
 'PSA_AWAY',
 'LBH_AWAY',
 'LBD_AWAY',
 'LBA_AWAY',
 'IWH_AWAY',
 'IWD_AWAY',
 'IWA_AWAY',
 'GBH_AWAY',
 'GBD_AWAY',
 'GBA_AWAY',
 'BWH_AWAY',
 'BWD_AWAY',
 'BWA_AWAY',
 'BSH_AWAY',
 'BSD_AWAY',
 'BSA_AWAY',
 'B365H_AWAY',
 'B365D_AWAY',
 'B365A_AWAY']

# %%
match_cols
# Out:
# ['stage',
#  'shoton',
#  'shotoff',
#  'season',
#  'possession',
#  'match_api_id',
#  'league_id',
#  'id',
#  'home_team_goal',
#  'home_team_api_id',
#  'home_player_Y9',
#  'home_player_Y8',
#  'home_player_Y7',
#  'home_player_Y6',
#  'home_player_Y5',
#  'home_player_Y4',
#  'home_player_Y3',
#  'home_player_Y2',
#  'home_player_Y11',
#  'home_player_Y10',
#  'home_player_Y1',
#  'home_player_X9',
#  'home_player_X8',
#  'home_player_X7',
#  'home_player_X6',
#  'home_player_X5',
#  'home_player_X4',
#  'home_player_X3',
#  'home_player_X2',
#  'home_player_X11',
#  'home_player_X10',
#  'home_player_X1',
#  'home_player_9',
#  'home_player_8',
#  'home_player_7',
#  'home_player_6',
#  'home_player_5',
#  'home_player_4',
#  'home_player_3',
#  'home_player_2',
#  'home_player_11',
#  'home_player_10',
#  'home_player_1',
#  'goal',
#  'foulcommit',
#  'date',
#  'cross',
#  'country_id',
#  'corner',
#  'card',
#  'away_team_goal',
#  'away_team_api_id',
# ...

# %%
match_merged.columns.rename()

# %%
remove_home_list = ['stage_HOME',
 'shoton_HOME',
 'shotoff_HOME',
 'season_HOME',
 'possession_HOME',
 'match_api_id_HOME',
 'league_id_HOME',
 'home_team_goal_HOME',
 'home_team_api_id_HOME',
 'home_player_Y9_HOME',
 'home_player_Y8_HOME',
 'home_player_Y7_HOME',
 'home_player_Y6_HOME',
 'home_player_Y5_HOME',
 'home_player_Y4_HOME',
 'home_player_Y3_HOME',
 'home_player_Y2_HOME',
 'home_player_Y11_HOME',
 'home_player_Y10_HOME',
 'home_player_Y1_HOME',
 'home_player_X9_HOME',
 'home_player_X8_HOME',
 'home_player_X7_HOME',
 'home_player_X6_HOME',
 'home_player_X5_HOME',
 'home_player_X4_HOME',
 'home_player_X3_HOME',
 'home_player_X2_HOME',
 'home_player_X11_HOME',
 'home_player_X10_HOME',
 'home_player_X1_HOME',
 'home_player_9_HOME',
 'home_player_8_HOME',
 'home_player_7_HOME',
 'home_player_6_HOME',
 'home_player_5_HOME',
 'home_player_4_HOME',
 'home_player_3_HOME',
 'home_player_2_HOME',
 'home_player_11_HOME',
 'home_player_10_HOME',
 'home_player_1_HOME',
 'goal_HOME',
 'foulcommit_HOME',
 'cross_HOME',
 'country_id_HOME',
 'corner_HOME',
 'card_HOME',
 'away_team_goal_HOME',
 'away_team_api_id_HOME',
 'away_player_Y9_HOME',
 'away_player_Y8_HOME',
 'away_player_Y7_HOME',
 'away_player_Y6_HOME',
 'away_player_Y5_HOME',
 'away_player_Y4_HOME',
 'away_player_Y3_HOME',
 'away_player_Y2_HOME',
 'away_player_Y11_HOME',
 'away_player_Y10_HOME',
 'away_player_Y1_HOME',
 'away_player_X9_HOME',
 'away_player_X8_HOME',
 'away_player_X7_HOME',
 'away_player_X6_HOME',
 'away_player_X5_HOME',
 'away_player_X4_HOME',
 'away_player_X3_HOME',
 'away_player_X2_HOME',
 'away_player_X11_HOME',
 'away_player_X10_HOME',
 'away_player_X1_HOME',
 'away_player_9_HOME',
 'away_player_8_HOME',
 'away_player_7_HOME',
 'away_player_6_HOME',
 'away_player_5_HOME',
 'away_player_4_HOME',
 'away_player_3_HOME',
 'away_player_2_HOME',
 'away_player_11_HOME',
 'away_player_10_HOME',
 'away_player_1_HOME',
 '_sa_instance_state_HOME',
 'WHH_HOME',
 'WHD_HOME',
 'WHA_HOME',
 'VCH_HOME',
 'VCD_HOME',
 'VCA_HOME',
 'SJH_HOME',
 'SJD_HOME',
 'SJA_HOME',
 'PSH_HOME',
 'PSD_HOME',
 'PSA_HOME',
 'LBH_HOME',
 'LBD_HOME',
 'LBA_HOME',
 'IWH_HOME',
 'IWD_HOME',
 'IWA_HOME',
 'GBH_HOME',
 'GBD_HOME',
 'GBA_HOME',
 'BWH_HOME',
 'BWD_HOME',
 'BWA_HOME',
 'BSH_HOME',
 'BSD_HOME',
 'BSA_HOME',
 'B365H_HOME',
 'B365D_HOME',
 'B365A_HOME']

# %%
transposed = match_merged.T

# %%
df = transposed.drop_duplicates().T

# %%
# for i in match_merged:
#     for j in match_merged:
#         print(i,j,"\n")
#         print(match_merged.duplicated(subset=[i,j],keep=False))
#     break
# Out:
# _sa_instance_state_HOME _sa_instance_state_HOME
#
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18238    False
# 18239    False
# 18240    False
# 18241    False
# 18242    False
# Length: 18243, dtype: bool
# _sa_instance_state_HOME home_player_4_HOME
#
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18238    False
# 18239    False
# 18240    False
# 18241    False
# 18242    False
# Length: 18243, dtype: bool
# _sa_instance_state_HOME BWA_HOME
#
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18238    False
# 18239    False
# 18240    False
# 18241    False
# 18242    False
# Length: 18243, dtype: bool
# _sa_instance_state_HOME VCH_HOME
#
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18238    False
# 18239    False
# 18240    False
# 18241    False
# 18242    False
# ...

# %%
ml_df_columns = [ 'away_team_api_id_HOME','stage_HOME',
 'shoton_HOME',
 'shotoff_HOME',
 'season_HOME',
 'possession_HOME',
 'home_team_goal_HOME',
 'home_team_api_id_HOME',
 'goal_HOME',
 'foulcommit_HOME',
 'defenceTeamWidth_HOME',
 'defenceTeamWidth_AWAY',
 'defenceTeamWidthClass_HOME',
 'defenceTeamWidthClass_AWAY',
 'defencePressure_HOME',
 'defencePressure_AWAY',
 'defencePressureClass_HOME',
 'defencePressureClass_AWAY',
 'defenceDefenderLineClass_HOME',
 'defenceDefenderLineClass_AWAY',
 'defenceAggression_HOME',
 'defenceAggression_AWAY',
 'defenceAggressionClass_HOME',
 'defenceAggressionClass_AWAY',
 'cross_HOME',
 'corner_HOME',
 'chanceCreationShooting_HOME',
 'chanceCreationShooting_AWAY',
 'chanceCreationShootingClass_HOME',
 'chanceCreationShootingClass_AWAY',
 'chanceCreationPositioningClass_HOME',
 'chanceCreationPositioningClass_AWAY',
 'chanceCreationPassing_HOME',
 'chanceCreationPassing_AWAY',
 'chanceCreationPassingClass_HOME',
 'chanceCreationPassingClass_AWAY',
 'chanceCreationCrossing_HOME',
 'chanceCreationCrossing_AWAY',
 'chanceCreationCrossingClass_HOME',
 'chanceCreationCrossingClass_AWAY',
 'card_HOME',
 'buildUpPlaySpeed_HOME',
 'buildUpPlaySpeed_AWAY',
 'buildUpPlaySpeedClass_HOME',
 'buildUpPlaySpeedClass_AWAY',
 'buildUpPlayPositioningClass_HOME',
 'buildUpPlayPositioningClass_AWAY',
 'buildUpPlayPassing_HOME',
 'buildUpPlayPassing_AWAY',
 'buildUpPlayPassingClass_HOME',
 'buildUpPlayPassingClass_AWAY',
 'buildUpPlayDribbling_HOME',
 'buildUpPlayDribbling_AWAY',
 'buildUpPlayDribblingClass_HOME',
 'buildUpPlayDribblingClass_AWAY',
 'away_team_goal_HOME',
 'YEAR',
 'WHH_HOME',
 'WHD_HOME',
 'WHA_HOME',
 'VCH_HOME',
 'VCD_HOME',
 'VCA_HOME',
 'SJH_HOME',
 'SJD_HOME',
 'SJA_HOME',
 'PSH_HOME',
 'PSD_HOME',
 'PSA_HOME',
 'LBH_HOME',
 'LBD_HOME',
 'LBA_HOME',
 'IWH_HOME',
 'IWD_HOME',
 'IWA_HOME',
 'GBH_HOME',
 'GBD_HOME',
 'GBA_HOME',
 'BWH_HOME',
 'BWD_HOME',
 'BWA_HOME',
 'BSH_HOME',
 'BSD_HOME',
 'BSA_HOME',
 'B365H_HOME',
 'B365D_HOME',
 'B365A_HOME']

# %%
ml_df = df.loc[:,ml_df_columns]

# %%
ml_df
# Out:
#       away_team_api_id_HOME stage_HOME shoton_HOME shotoff_HOME season_HOME  \
# 0                      8342         19        None         None   2009/2010
# 1                      9997         25        None         None   2009/2010
# 2                      8203         27        None         None   2009/2010
# 3                      9987         29        None         None   2009/2010
# 4                     10001         12        None         None   2010/2011
# ...                     ...        ...         ...          ...         ...
# 18238                 10199         15        None         None   2015/2016
# 18239                 10191         17  <shoton />  <shotoff />   2015/2016
# 18240                 10190          2        None         None   2015/2016
# 18241                 10243          5        None         None   2015/2016
# 18242                 10192          6        None         None   2015/2016
#
# ...

# %%
ml_df.loc[ml_df['shoton_HOME'] == '<shoton />',]
# Out:
#       away_team_api_id_HOME stage_HOME shoton_HOME shotoff_HOME season_HOME  \
# 3291                   9851         11  <shoton />  <shotoff />   2010/2011
# 3294                   9748         18  <shoton />  <shotoff />   2010/2011
# 3313                   9853         17  <shoton />  <shotoff />   2010/2011
# 3314                   9874         19  <shoton />  <shotoff />   2010/2011
# 3343                   8592         17  <shoton />  <shotoff />   2010/2011
# ...                     ...        ...         ...          ...         ...
# 18144                  9824         18  <shoton />  <shotoff />   2015/2016
# 18178                 10199         17  <shoton />  <shotoff />   2015/2016
# 18196                 10179         18  <shoton />  <shotoff />   2015/2016
# 18212                 10190         17  <shoton />  <shotoff />   2015/2016
# 18239                 10191         17  <shoton />  <shotoff />   2015/2016
#
# ...

# %%
ml_df.loc[pd.notnull(ml_df['possession_HOME']),]
# Out:
#       away_team_api_id_HOME stage_HOME  \
# 1005                   9879         17
# 1006                   8650         22
# 1007                   8456         23
# 1008                   8655         25
# 1009                   9825         28
# ...                     ...        ...
# 18144                  9824         18
# 18178                 10199         17
# 18196                 10179         18
# 18212                 10190         17
# 18239                 10191         17
#
#                                              shoton_HOME  \
# 1005   <shoton><value><stats><shoton>1</shoton></stat...
# 1006   <shoton><value><stats><blocked>1</blocked></st...
# 1007   <shoton><value><stats><shoton>1</shoton></stat...
# 1008   <shoton><value><stats><blocked>1</blocked></st...
# 1009   <shoton><value><stats><blocked>1</blocked></st...
# ...                                                  ...
# 18144                                         <shoton />
# ...

# %%
countInstances(ml_df.shoton_HOME,'shoton_HOME','<shoton>1')
# Out:
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# typeError None
# ...

# %%
ml_df['shoton_HOME'].value_counts()
# Out:
# 0     4745
# 6      890
# 5      801
# 7      753
# 8      735
# 4      651
# 9      490
# 3      436
# 10     400
# 11     230
# 2      211
# 12     169
# 13     129
# 1       84
# 14      49
# 15      29
# 16      14
# 17      10
# 18       5
# 20       3
# 21       1
# Name: shoton_HOME, dtype: int64

# %%
def countInstances(df_WITH_column,columnName, splitvaluestring):
    
    for idx, i in enumerate(df_WITH_column):
        try:
            if '<' in i:
                shotoffval = len(i.split(splitvaluestring)) - 1
                ml_df.loc[idx, columnName] = shotoffval
            else:
                print(i)
        except TypeError:
            print('typeError',i)

# %%
pd.set_option('display.max_columns', None)

# %%
rf_df = ml_df.drop(columns=['goal_HOME', 'foulcommit_HOME','possession_HOME', 'cross_HOME','corner_HOME','card_HOME','season_HOME','stage_HOME'])

# %%
rf_df
# Out:
#       away_team_api_id_HOME shoton_HOME shotoff_HOME home_team_goal_HOME  \
# 0                      8342        None         None                   3
# 1                      9997        None         None                   1
# 2                      8203        None         None                   2
# 3                      9987        None         None                   2
# 4                     10001        None         None                   2
# ...                     ...         ...          ...                 ...
# 18238                 10199        None         None                   2
# 18239                 10191           0  <shotoff />                   1
# 18240                 10190        None         None                   1
# 18241                 10243        None         None                   3
# 18242                 10192        None         None                   1
#
#       home_team_api_id_HOME defenceTeamWidth_HOME defenceTeamWidth_AWAY  \
# ...

# %%
numbertypecols = ['shoton_HOME	shotoff_HOME home_team_goal_HOME	defenceTeamWidth_HOME	defenceTeamWidth_AWAY defencePressure_HOME	defencePressure_AWAY	defenceAggression_HOME	defenceAggression_AWAY chanceCreationShooting_HOME	chanceCreationShooting_AWAYchanceCreationPassing_HOME	chanceCreationPassing_AWAY chanceCreationCrossing_HOME	chanceCreationCrossing_AWAY buildUpPlaySpeed_HOME	buildUpPlaySpeed_AWAY buildUpPlayPassing_HOME	buildUpPlayPassing_AWAY	 buildUpPlayDribbling_HOME	buildUpPlayDribbling_AWAY away_team_goal_HOME WHH_HOME	WHD_HOME	WHA_HOME	VCH_HOME	VCD_HOME	VCA_HOME	SJH_HOME	SJD_HOME	SJA_HOME	PSH_HOME	PSD_HOME	PSA_HOME	LBH_HOME	LBD_HOME	LBA_HOME	IWH_HOME	IWD_HOME	IWA_HOME	GBH_HOME	GBD_HOME	GBA_HOME	BWH_HOME	BWD_HOME	BWA_HOME	BSH_HOME	BSD_HOME	BSA_HOME	B365H_HOME	B365D_HOME	B365A_HOME']

# %%
numbertypecols = pd.Series(numbertypecols)

# %%
numbertypecols = numbertypecols.str.split()

# %%
numbertypecols = numbertypecols[0]

# %%
rf_df['gameoutcome'] = rf_df['away_team_goal_HOME'] - rf_df['home_team_goal_HOME']

# %%
import numpy as np
listie = []
for i in rf_df['gameoutcome']:
    if i > 0:
    #away win
        winval = 0
    elif i < 0:
        #home win
        winval = 1
    else:
        winval = np.nan
    listie.append(winval)
rf_df['y'] = listie

# %%
listie = []
for i in rf_df.columns:
    if i not in numbertypecols:
        listie.append(i)
    else:
        print('wow')
listie
# Out:
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# wow
# ['away_team_api_id_HOME',
#  'home_team_api_id_HOME',
#  'defenceTeamWidthClass_HOME',
#  'defenceTeamWidthClass_AWAY',
#  'defencePressureClass_HOME',
#  'defencePressureClass_AWAY',
#  'defenceDefenderLineClass_HOME',
#  'defenceDefenderLineClass_AWAY',
#  'defenceAggressionClass_HOME',
#  'defenceAggressionClass_AWAY',
#  'chanceCreationShooting_AWAY',
#  'chanceCreationShootingClass_HOME',
#  'chanceCreationShootingClass_AWAY',
#  'chanceCreationPositioningClass_HOME',
#  'chanceCreationPositioningClass_AWAY',
#  'chanceCreationPassing_HOME',
#  'chanceCreationPassingClass_HOME',
#  'chanceCreationPassingClass_AWAY',
#  'chanceCreationCrossingClass_HOME',
# ...

# %%
rf_df
# Out:
#       away_team_api_id_HOME shoton_HOME shotoff_HOME home_team_goal_HOME  \
# 0                      8342        None         None                   3
# 1                      9997        None         None                   1
# 2                      8203        None         None                   2
# 3                      9987        None         None                   2
# 4                     10001        None         None                   2
# ...                     ...         ...          ...                 ...
# 18238                 10199        None         None                   2
# 18239                 10191           0  <shotoff />                   1
# 18240                 10190        None         None                   1
# 18241                 10243        None         None                   3
# 18242                 10192        None         None                   1
#
#       home_team_api_id_HOME defenceTeamWidth_HOME defenceTeamWidth_AWAY  \
# ...

# %%
categoricalcols = [
 'defenceTeamWidthClass_HOME',
 'defenceTeamWidthClass_AWAY',
 'defencePressureClass_HOME',
 'defencePressureClass_AWAY',
 'defenceDefenderLineClass_HOME',
 'defenceDefenderLineClass_AWAY',
 'defenceAggressionClass_HOME',
 'defenceAggressionClass_AWAY',
 'chanceCreationShootingClass_HOME',
 'chanceCreationShootingClass_AWAY',
 'chanceCreationPositioningClass_HOME',
 'chanceCreationPositioningClass_AWAY',
 'chanceCreationPassingClass_HOME',
 'chanceCreationPassingClass_AWAY',
 'chanceCreationCrossingClass_HOME',
 'chanceCreationCrossingClass_AWAY',
 'buildUpPlaySpeedClass_HOME',
 'buildUpPlaySpeedClass_AWAY',
 'buildUpPlayPositioningClass_HOME',
 'buildUpPlayPositioningClass_AWAY',
 'buildUpPlayPassingClass_HOME',
 'buildUpPlayPassingClass_AWAY',
 'buildUpPlayDribblingClass_HOME',
 'buildUpPlayDribblingClass_AWAY', 'away_team_api_id_HOME','home_team_api_id_HOME']

# %%
df = pd.get_dummies(rf_df,columns=categoricalcols,drop_first=True).drop(columns=['home_team_goal_HOME', 'away_team_goal_HOME','gameoutcome','shoton_HOME','shotoff_HOME'])

# %%
df.to_csv('./dummied_teamid_ml_df.csv')

# %%
df
# Out:
#       defenceTeamWidth_HOME defenceTeamWidth_AWAY defencePressure_HOME  \
# 0                        70                    70                   70
# 1                        70                    50                   70
# 2                        70                    60                   70
# 3                        70                    70                   70
# 4                        70                    70                   70
# ...                     ...                   ...                  ...
# 18238                    54                    50                   45
# 18239                    54                    53                   45
# 18240                    54                    52                   45
# 18241                    54                    56                   45
# 18242                    54                    50                   45
#
#       defencePressure_AWAY defenceAggression_HOME defenceAggression_AWAY  \
# ...
