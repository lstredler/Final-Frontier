# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pandas as pd

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///C:/Users/JoshWeidenaar/Downloads/database.sqlite")

# %%
engine
# Out:
# Engine(sqlite:///C:/Users/JoshWeidenaar/Downloads/database.sqlite)

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# Create a session
session = Session(engine)

# %%
# Print all of the classes mapped to the Base
classes = Base.classes.keys()

# %%
df_dict = {}

for i in classes:
    class_call = Base.classes[i]
    class_data = session.query(class_call).all()
    listie_dicts = []
    for j in class_data:
        listie_dicts.append(j.__dict__)
    df_dict[i] = pd.DataFrame(listie_dicts)
# Out:
# C:\Users\JoshWeidenaar\anaconda3\lib\site-packages\sqlalchemy\sql\sqltypes.py:661: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   util.warn(

# %%
country_id = df_dict['country']['id']
country_id_LEAGUE = df_dict['League']['country_id']
league_id = df_dict['League']['id']

# %%
league_id_MATCH = df_dict['Match']['league_id']
country_id_MATCH = df_dict['Match']['country_id']
home_team_api_id_MATCH = df_dict['Match']['home_team_api_id']
away_team_api_id_MATCH = df_dict['Match']['away_team_api_id'] 
player_id_MATCH = []#any attr in Match table that has the word "player" in it
player_id = df_dict['Player']['id']
player_api_id = df_dict['Player']['player_api_id']
player_fifa_id = df_dict['Player']['player_fifa_api_id']
player_attr_id = df_dict['Player_Attributes']['id']
player_id_ATTRS = df_dict['Player_Attributes']['player_api_id']
player_fifa_id_ATTRS = df_dict['Player_Attributes']['player_fifa_api_id']
team_fifa_id = df_dict['Team']['team_fifa_api_id']
team_id = df_dict['Team']['id']
team_api_id = df_dict['Team']['team_api_id']
team_id_ATTRS = df_dict['Team_Attributes']['team_api_id']
team_fifa_id_ATTRS = df_dict['Team_Attributes']['team_fifa_api_id']

# %%
player_merged = pd.merge(df_dict['Player'],df_dict['Player_Attributes'],left_on=player_api_id,right_on=player_id_ATTRS)

# %%
player_merged
# Out:
#      key_0                               _sa_instance_state_x  \
# 0   505942  <sqlalchemy.orm.state.InstanceState object at ...
# 1   505942  <sqlalchemy.orm.state.InstanceState object at ...
# 2   505942  <sqlalchemy.orm.state.InstanceState object at ...
# 3   505942  <sqlalchemy.orm.state.InstanceState object at ...
# 4   505942  <sqlalchemy.orm.state.InstanceState object at ...
# 5   155782  <sqlalchemy.orm.state.InstanceState object at ...
# 6   155782  <sqlalchemy.orm.state.InstanceState object at ...
# 7   155782  <sqlalchemy.orm.state.InstanceState object at ...
# 8   155782  <sqlalchemy.orm.state.InstanceState object at ...
# 9   155782  <sqlalchemy.orm.state.InstanceState object at ...
# 10  155782  <sqlalchemy.orm.state.InstanceState object at ...
# 11  155782  <sqlalchemy.orm.state.InstanceState object at ...
# 12  155782  <sqlalchemy.orm.state.InstanceState object at ...
# 13  155782  <sqlalchemy.orm.state.InstanceState object at ...
# 14  155782  <sqlalchemy.orm.state.InstanceState object at ...
# 15  155782  <sqlalchemy.orm.state.InstanceState object at ...
# 16  155782  <sqlalchemy.orm.state.InstanceState object at ...
#
# 43                186170           162549     163  1991-05-13 00:00:00
# 44                186170           162549     163  1991-05-13 00:00:00
#
#            player_name  id_x  height  \
# 0   Aaron Appindangoye     1  182.88
# 1   Aaron Appindangoye     1  182.88
# 2   Aaron Appindangoye     1  182.88
# 3   Aaron Appindangoye     1  182.88
# 4   Aaron Appindangoye     1  182.88
# 5      Aaron Cresswell     2  170.18
# 6      Aaron Cresswell     2  170.18
# 7      Aaron Cresswell     2  170.18
# 8      Aaron Cresswell     2  170.18
# 9      Aaron Cresswell     2  170.18
# 10     Aaron Cresswell     2  170.18
# 11     Aaron Cresswell     2  170.18
# 12     Aaron Cresswell     2  170.18
# 13     Aaron Cresswell     2  170.18
# 14     Aaron Cresswell     2  170.18
# 15     Aaron Cresswell     2  170.18
# 16     Aaron Cresswell     2  170.18
# 17     Aaron Cresswell     2  170.18
# 18     Aaron Cresswell     2  170.18
# 19     Aaron Cresswell     2  170.18
# 20     Aaron Cresswell     2  170.18
# 21     Aaron Cresswell     2  170.18
# 22     Aaron Cresswell     2  170.18
# 23     Aaron Cresswell     2  170.18
# 24     Aaron Cresswell     2  170.18
# 25     Aaron Cresswell     2  170.18
# 26     Aaron Cresswell     2  170.18
# 27     Aaron Cresswell     2  170.18
# 28     Aaron Cresswell     2  170.18
# 29     Aaron Cresswell     2  170.18
# 30     Aaron Cresswell     2  170.18
# 31     Aaron Cresswell     2  170.18
# 32     Aaron Cresswell     2  170.18
# 33     Aaron Cresswell     2  170.18
# 34     Aaron Cresswell     2  170.18
# 35     Aaron Cresswell     2  170.18
# 36     Aaron Cresswell     2  170.18
# 37     Aaron Cresswell     2  170.18
# 38         Aaron Doran     3  170.18
# 39         Aaron Doran     3  170.18
# 40         Aaron Doran     3  170.18
# 41         Aaron Doran     3  170.18
# 42         Aaron Doran     3  170.18
# 43         Aaron Doran     3  170.18
# 44         Aaron Doran     3  170.18
#
#                                  _sa_instance_state_y  ... sliding_tackle  \
# 0   <sqlalchemy.orm.state.InstanceState object at ...  ...           69.0
# 1   <sqlalchemy.orm.state.InstanceState object at ...  ...           69.0
# 2   <sqlalchemy.orm.state.InstanceState object at ...  ...           69.0
# 3   <sqlalchemy.orm.state.InstanceState object at ...  ...           66.0
# 4   <sqlalchemy.orm.state.InstanceState object at ...  ...           66.0
# 5   <sqlalchemy.orm.state.InstanceState object at ...  ...           78.0
# 6   <sqlalchemy.orm.state.InstanceState object at ...  ...           78.0
# 7   <sqlalchemy.orm.state.InstanceState object at ...  ...           78.0
# 8   <sqlalchemy.orm.state.InstanceState object at ...  ...           78.0
# 9   <sqlalchemy.orm.state.InstanceState object at ...  ...           78.0
# 10  <sqlalchemy.orm.state.InstanceState object at ...  ...           78.0
# 11  <sqlalchemy.orm.state.InstanceState object at ...  ...           78.0
# 12  <sqlalchemy.orm.state.InstanceState object at ...  ...           78.0
# 13  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 14  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 15  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 16  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 17  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 18  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 19  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 20  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 21  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 22  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 23  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 24  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 25  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 26  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 27  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 28  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 29  <sqlalchemy.orm.state.InstanceState object at ...  ...           72.0
# 30  <sqlalchemy.orm.state.InstanceState object at ...  ...           67.0
# 31  <sqlalchemy.orm.state.InstanceState object at ...  ...           67.0
# 32  <sqlalchemy.orm.state.InstanceState object at ...  ...           63.0
# 33  <sqlalchemy.orm.state.InstanceState object at ...  ...           63.0
# 34  <sqlalchemy.orm.state.InstanceState object at ...  ...           63.0
# 35  <sqlalchemy.orm.state.InstanceState object at ...  ...           63.0
# 36  <sqlalchemy.orm.state.InstanceState object at ...  ...           63.0
# 37  <sqlalchemy.orm.state.InstanceState object at ...  ...           63.0
# 38  <sqlalchemy.orm.state.InstanceState object at ...  ...           24.0
# 39  <sqlalchemy.orm.state.InstanceState object at ...  ...           24.0
# 40  <sqlalchemy.orm.state.InstanceState object at ...  ...           24.0
# 41  <sqlalchemy.orm.state.InstanceState object at ...  ...           21.0
# 42  <sqlalchemy.orm.state.InstanceState object at ...  ...           21.0
# 43  <sqlalchemy.orm.state.InstanceState object at ...  ...           21.0
# 44  <sqlalchemy.orm.state.InstanceState object at ...  ...           21.0
#
#     short_passing  long_shots  interceptions  potential agility  gk_diving  \
# 0            61.0        35.0           70.0       71.0    59.0        6.0
# 1            61.0        35.0           70.0       71.0    59.0        6.0
# 2            61.0        35.0           41.0       66.0    59.0        6.0
# 3            60.0        34.0           40.0       65.0    59.0        5.0
# 4            60.0        34.0           40.0       65.0    59.0        5.0
# 5            71.0        62.0           67.0       76.0    78.0       14.0
# 6            71.0        60.0           67.0       76.0    78.0       14.0
# 7            70.0        59.0           66.0       75.0    78.0       14.0
# 8            70.0        58.0           66.0       75.0    78.0       14.0
# 9            70.0        58.0           66.0       75.0    78.0       14.0
# 10           70.0        58.0           66.0       77.0    78.0       14.0
# 11           70.0        58.0           66.0       78.0    78.0       14.0
# 31     30.0        64.0       62.0
# 32     30.0        64.0       44.0
# 33     30.0        63.0       43.0
# 34     30.0        64.0       44.0
# 35     30.0        64.0       26.0
# 36     30.0        64.0       26.0
# 37     30.0        64.0       26.0
# 38     52.0        60.0       66.0
# 39     52.0        60.0       66.0
# 40     52.0        60.0       66.0
# 41     51.0        59.0       66.0
# 42     51.0        59.0       69.0
# 43     51.0        59.0       69.0
# 44     51.0        59.0       69.0
#
# [45 rows x 52 columns]

# %%
sqlite_ddl = """CREATE TABLE "Country" (
	"id"	INTEGER,
	"name"	TEXT UNIQUE,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "League" (
	"id"	INTEGER,
	"country_id"	INTEGER,
	"name"	TEXT UNIQUE,
	FOREIGN KEY("country_id") REFERENCES "country"("id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Match" (
	"id"	INTEGER,
	"country_id"	INTEGER,
	"league_id"	INTEGER,
	"season"	TEXT,
	"stage"	INTEGER,
	"date"	TEXT,
	"match_api_id"	INTEGER UNIQUE,
	"home_team_api_id"	INTEGER,
	"away_team_api_id"	INTEGER,
	"home_team_goal"	INTEGER,
	"away_team_goal"	INTEGER,
	"home_player_X1"	INTEGER,
	"home_player_X2"	INTEGER,
	"home_player_X3"	INTEGER,
	"home_player_X4"	INTEGER,
	"home_player_X5"	INTEGER,
	"home_player_X6"	INTEGER,
	"home_player_X7"	INTEGER,
	"home_player_X8"	INTEGER,
	"home_player_X9"	INTEGER,
	"home_player_X10"	INTEGER,
	"home_player_X11"	INTEGER,
	"away_player_X1"	INTEGER,
	"away_player_X2"	INTEGER,
	"away_player_X3"	INTEGER,
	"away_player_X4"	INTEGER,
	"away_player_X5"	INTEGER,
	"away_player_X6"	INTEGER,
	"away_player_X7"	INTEGER,
	"away_player_X8"	INTEGER,
	"away_player_X9"	INTEGER,
	"away_player_X10"	INTEGER,
	"away_player_X11"	INTEGER,
	"home_player_Y1"	INTEGER,
	"home_player_Y2"	INTEGER,
	"home_player_Y3"	INTEGER,
	"home_player_Y4"	INTEGER,
	"home_player_Y5"	INTEGER,
	"home_player_Y6"	INTEGER,
	"home_player_Y7"	INTEGER,
	"home_player_Y8"	INTEGER,
	"home_player_Y9"	INTEGER,
	"home_player_Y10"	INTEGER,
	"home_player_Y11"	INTEGER,
	"away_player_Y1"	INTEGER,
	"away_player_Y2"	INTEGER,
	"away_player_Y3"	INTEGER,
	"away_player_Y4"	INTEGER,
	"away_player_Y5"	INTEGER,
	"away_player_Y6"	INTEGER,
	"away_player_Y7"	INTEGER,
	"away_player_Y8"	INTEGER,
	"away_player_Y9"	INTEGER,
	"away_player_Y10"	INTEGER,
	"away_player_Y11"	INTEGER,
	"home_player_1"	INTEGER,
	"home_player_2"	INTEGER,
	"home_player_3"	INTEGER,
	"home_player_4"	INTEGER,
	"home_player_5"	INTEGER,
	"home_player_6"	INTEGER,
	"home_player_7"	INTEGER,
	"home_player_8"	INTEGER,
	"home_player_9"	INTEGER,
	"home_player_10"	INTEGER,
	"home_player_11"	INTEGER,
	"away_player_1"	INTEGER,
	"away_player_2"	INTEGER,
	"away_player_3"	INTEGER,
	"away_player_4"	INTEGER,
	"away_player_5"	INTEGER,
	"away_player_6"	INTEGER,
	"away_player_7"	INTEGER,
	"away_player_8"	INTEGER,
	"away_player_9"	INTEGER,
	"away_player_10"	INTEGER,
	"away_player_11"	INTEGER,
	"goal"	TEXT,
	"shoton"	TEXT,
	"shotoff"	TEXT,
	"foulcommit"	TEXT,
	"card"	TEXT,
	"cross"	TEXT,
	"corner"	TEXT,
	"possession"	TEXT,
	"B365H"	NUMERIC,
	"B365D"	NUMERIC,
	"B365A"	NUMERIC,
	"BWH"	NUMERIC,
	"BWD"	NUMERIC,
	"BWA"	NUMERIC,
	"IWH"	NUMERIC,
	"IWD"	NUMERIC,
	"IWA"	NUMERIC,
	"LBH"	NUMERIC,
	"LBD"	NUMERIC,
	"LBA"	NUMERIC,
	"PSH"	NUMERIC,
	"PSD"	NUMERIC,
	"PSA"	NUMERIC,
	"WHH"	NUMERIC,
	"WHD"	NUMERIC,
	"WHA"	NUMERIC,
	"SJH"	NUMERIC,
	"SJD"	NUMERIC,
	"SJA"	NUMERIC,
	"VCH"	NUMERIC,
	"VCD"	NUMERIC,
	"VCA"	NUMERIC,
	"GBH"	NUMERIC,
	"GBD"	NUMERIC,
	"GBA"	NUMERIC,
	"BSH"	NUMERIC,
	"BSD"	NUMERIC,
	"BSA"	NUMERIC,
	FOREIGN KEY("home_player_9") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_1") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_10") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_2") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_3") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_4") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_5") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_6") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_11") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_5") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_7") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_4") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_9") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_10") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_7") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_6") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_8") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_player_8") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("away_team_api_id") REFERENCES "Team"("team_api_id"),
	FOREIGN KEY("home_player_1") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_3") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("home_player_2") REFERENCES "Player"("player_api_id"),
	FOREIGN KEY("country_id") REFERENCES "country"("id"),
	FOREIGN KEY("league_id") REFERENCES "League"("id"),
	FOREIGN KEY("home_team_api_id") REFERENCES "Team"("team_api_id"),
	FOREIGN KEY("away_player_11") REFERENCES "Player"("player_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Player" (
	"id"	INTEGER,
	"player_api_id"	INTEGER UNIQUE,
	"player_name"	TEXT,
	"player_fifa_api_id"	INTEGER UNIQUE,
	"birthday"	TEXT,
	"height"	INTEGER,
	"weight"	INTEGER,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
​
CREATE TABLE "Player_Attributes" (
	"id"	INTEGER,
	"player_fifa_api_id"	INTEGER,
	"player_api_id"	INTEGER,
	"date"	TEXT,
	"overall_rating"	INTEGER,
	"potential"	INTEGER,
	"preferred_foot"	TEXT,
	"attacking_work_rate"	TEXT,
	"defensive_work_rate"	TEXT,
	"crossing"	INTEGER,
	"finishing"	INTEGER,
	"heading_accuracy"	INTEGER,
	"short_passing"	INTEGER,
	"volleys"	INTEGER,
	"dribbling"	INTEGER,
	"curve"	INTEGER,
	"free_kick_accuracy"	INTEGER,
	"long_passing"	INTEGER,
	"ball_control"	INTEGER,
	"acceleration"	INTEGER,
	"sprint_speed"	INTEGER,
	"agility"	INTEGER,
	"reactions"	INTEGER,
	"balance"	INTEGER,
	"shot_power"	INTEGER,
	"jumping"	INTEGER,
	"stamina"	INTEGER,
	"strength"	INTEGER,
	"long_shots"	INTEGER,
	"aggression"	INTEGER,
	"interceptions"	INTEGER,
	"positioning"	INTEGER,
	"vision"	INTEGER,
	"penalties"	INTEGER,
	"marking"	INTEGER,
	"standing_tackle"	INTEGER,
	"sliding_tackle"	INTEGER,
	"gk_diving"	INTEGER,
	"gk_handling"	INTEGER,
	"gk_kicking"	INTEGER,
	"gk_positioning"	INTEGER,
	"gk_reflexes"	INTEGER,
	FOREIGN KEY("player_fifa_api_id") REFERENCES "Player"("player_fifa_api_id"),
	FOREIGN KEY("player_api_id") REFERENCES "Player"("player_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Team" (
	"id"	INTEGER,
	"team_api_id"	INTEGER UNIQUE,
	"team_fifa_api_id"	INTEGER,
	"team_long_name"	TEXT,
	"team_short_name"	TEXT,
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "Team_Attributes" (
	"id"	INTEGER,
	"team_fifa_api_id"	INTEGER,
	"team_api_id"	INTEGER,
	"date"	TEXT,
	"buildUpPlaySpeed"	INTEGER,
	"buildUpPlaySpeedClass"	TEXT,
	"buildUpPlayDribbling"	INTEGER,
	"buildUpPlayDribblingClass"	TEXT,
	"buildUpPlayPassing"	INTEGER,
	"buildUpPlayPassingClass"	TEXT,
	"buildUpPlayPositioningClass"	TEXT,
	"chanceCreationPassing"	INTEGER,
	"chanceCreationPassingClass"	TEXT,
	"chanceCreationCrossing"	INTEGER,
	"chanceCreationCrossingClass"	TEXT,
	"chanceCreationShooting"	INTEGER,
	"chanceCreationShootingClass"	TEXT,
	"chanceCreationPositioningClass"	TEXT,
	"defencePressure"	INTEGER,
	"defencePressureClass"	TEXT,
	"defenceAggression"	INTEGER,
	"defenceAggressionClass"	TEXT,
	"defenceTeamWidth"	INTEGER,
	"defenceTeamWidthClass"	TEXT,
	"defenceDefenderLineClass"	TEXT,
	FOREIGN KEY("team_fifa_api_id") REFERENCES "Team"("team_fifa_api_id"),
	FOREIGN KEY("team_api_id") REFERENCES "Team"("team_api_id"),
	PRIMARY KEY("id" AUTOINCREMENT)
);
​
CREATE TABLE "sqlite_sequence" (
	"name"	,
	"seq"
);"""
